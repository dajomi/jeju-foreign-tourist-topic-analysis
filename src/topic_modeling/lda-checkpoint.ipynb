# %%
import pandas as pd

# %%
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
path = 'C:/Users/Administrator/Desktop/LDA/1_360.csv'

# %%
review = pd.read_csv(path)

# %%
only_review = review['review']
only_review.head()
# Out:
# 0    Hyeopjae Beach is arguably the most picturesqu...
# 1     Nice views, nice place to take pictures, not ...
# 2     Don't judge, I know it was cold and all but w...
# 3     Beautiful beach in a hip area. Plenty of rent...
# 4     Very good for relax and some swimming (water ...
# Name: review, dtype: object

# %%
from nltk.tokenize import RegexpTokenizer

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
only_review = only_review[:51]
print(len(only_review))
# Out:
# 51

# %%
only_review
# Out:
# 0     Hyeopjae Beach is arguably the most picturesqu...
# 1      Nice views, nice place to take pictures, not ...
# 2      Don't judge, I know it was cold and all but w...
# 3      Beautiful beach in a hip area. Plenty of rent...
# 4      Very good for relax and some swimming (water ...
# 5     Wonderful beach in Jeju island. Very clear wat...
# 6      The beach by bus is easy to get to the bus st...
# 7     Car parking near the beach is a nightmare... t...
# 8      Water was very clear and sand was clean. Ther...
# 9     My girlfriend and I went for a walk here and s...
# 10    We visited this beautiful beach as part of the...
# 11     We go to Hyeopjae beach whenever in Jeju, lov...
# 12     Of the beaches we visited in Jeju, this one w...
# 13    The beach is nice with a combination of sand a...
# 14    Visited Monsanto cafe and found there are afew...
# 15     The colour of Hyeopjae beach is real. it is n...
# 16     One of the best beaches in Jeju, we loved thi...
# 17    Beautiful sand beach.Couldn't swim coz we visi...
# 18    We are so glad we managed to catch such a beau...
# 19    Wonderful beach. I stayed a short while and ha...
# 20    It's beautiful but really cold. I dipped my fo...
# 21     Went to hyeopjae beach just to try swimming w...
# 22     If you wanna experience to swim in the ocean ...
# 23     This beach is adjecent to GeumNeung Beach - y...
# 24     I stayed here  for a couple of hours, swam, e...
# 25     This beach is good and definitely worth visit...
# 26     Stayed by Hyeopjae beach two nights, wish we ...
# 27     We had a much better time here than at Hamdeo...
# 28     This beach is one of the most beariful beache...
# 29     This stretch of beach is very near Hallim par...
# 30     I visited 4 different beaches in Jeju. They a...
# 31    I and my wife went to this beach as this beach...
# 32     The tourist industry is creative. So they dis...
# 33     Too bad we went in fall, I would have so want...
# 34    Very beautiful beach although one has to pay a...
# 35     If you are coming from a country with lots of...
# 36     Love this beach! Sand was soft and the sea wa...
# 37    This beach was really clean and had many food ...
# 38     Worth a visit if you are a beach person - lot...
# 39     White sand, clear water. View of several isla...
# 40    It's a tourist packed beach in the summer time...
# 41     We have visited this beach on our first day i...
# 42    Even during slightly overcast conditions this ...
# 43     Fish and chip shop with Aussie beers, wines a...
# 44     We originally got the bus here to go to halli...
# 45    Very lovely and shallow beach so good for snor...
# 46    This is not your traditional beach. It is quit...
# 47    This is a great beach with the most beautiful ...
# 48    Spent a Sunday morning relaxing on this magnif...
# 49    We are staying near to here and stopped on a d...
# 50     This is one of the most beautiful beaches in ...
# Name: review, dtype: object

# %%
for idx in range(len(only_review)):
    only_review[idx] = tokenizer.tokenize(only_review[idx])

# %%
only_review
# Out:
# 0     [Hyeopjae, Beach, is, arguably, the, most, pic...
# 1     [Nice, views, nice, place, to, take, pictures,...
# 2     [Don, t, judge, I, know, it, was, cold, and, a...
# 3     [Beautiful, beach, in, a, hip, area, Plenty, o...
# 4     [Very, good, for, relax, and, some, swimming, ...
# 5     [Wonderful, beach, in, Jeju, island, Very, cle...
# 6     [The, beach, by, bus, is, easy, to, get, to, t...
# 7     [Car, parking, near, the, beach, is, a, nightm...
# 8     [Water, was, very, clear, and, sand, was, clea...
# 9     [My, girlfriend, and, I, went, for, a, walk, h...
# 10    [We, visited, this, beautiful, beach, as, part...
# 11    [We, go, to, Hyeopjae, beach, whenever, in, Je...
# 12    [Of, the, beaches, we, visited, in, Jeju, this...
# 13    [The, beach, is, nice, with, a, combination, o...
# 14    [Visited, Monsanto, cafe, and, found, there, a...
# 15    [The, colour, of, Hyeopjae, beach, is, real, i...
# 16    [One, of, the, best, beaches, in, Jeju, we, lo...
# 17    [Beautiful, sand, beach, Couldn, t, swim, coz,...
# 18    [We, are, so, glad, we, managed, to, catch, su...
# 19    [Wonderful, beach, I, stayed, a, short, while,...
# 20    [It, s, beautiful, but, really, cold, I, dippe...
# 21    [Went, to, hyeopjae, beach, just, to, try, swi...
# 22    [If, you, wanna, experience, to, swim, in, the...
# 23    [This, beach, is, adjecent, to, GeumNeung, Bea...
# 24    [I, stayed, here, for, a, couple, of, hours, s...
# 25    [This, beach, is, good, and, definitely, worth...
# 26    [Stayed, by, Hyeopjae, beach, two, nights, wis...
# 27    [We, had, a, much, better, time, here, than, a...
# 28    [This, beach, is, one, of, the, most, beariful...
# 29    [This, stretch, of, beach, is, very, near, Hal...
# 30    [I, visited, 4, different, beaches, in, Jeju, ...
# 31    [I, and, my, wife, went, to, this, beach, as, ...
# 32    [The, tourist, industry, is, creative, So, the...
# 33    [Too, bad, we, went, in, fall, I, would, have,...
# 34    [Very, beautiful, beach, although, one, has, t...
# 35    [If, you, are, coming, from, a, country, with,...
# 36    [Love, this, beach, Sand, was, soft, and, the,...
# 37    [This, beach, was, really, clean, and, had, ma...
# 38    [Worth, a, visit, if, you, are, a, beach, pers...
# 39    [White, sand, clear, water, View, of, several,...
# 40    [It, s, a, tourist, packed, beach, in, the, su...
# 41    [We, have, visited, this, beach, on, our, firs...
# 42    [Even, during, slightly, overcast, conditions,...
# 43    [Fish, and, chip, shop, with, Aussie, beers, w...
# 44    [We, originally, got, the, bus, here, to, go, ...
# 45    [Very, lovely, and, shallow, beach, so, good, ...
# 46    [This, is, not, your, traditional, beach, It, ...
# 47    [This, is, a, great, beach, with, the, most, b...
# 48    [Spent, a, Sunday, morning, relaxing, on, this...
# 49    [We, are, staying, near, to, here, and, stoppe...
# 50    [This, is, one, of, the, most, beautiful, beac...
# Name: review, dtype: object

# %%
only_review = [[token for token in doc if len(token) > 1] for doc in only_review]

# %%
# 불용어 처리

import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 
stop_words.add('wa')
stop_words.add('it')
stop_words.add('don')
stop_words.add('if')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
result = []

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
docs = [[lemmatizer.lemmatize(token) for token in doc] for doc in only_review]

# %%
docs
# Out:
# [['Hyeopjae',
#   'Beach',
#   'is',
#   'arguably',
#   'the',
#   'most',
#   'picturesque',
#   'beach',
#   'in',
#   'Jeju',
#   'The',
#   'emerald',
#   'colored',
#   'water',
#   'look',
#   'beautiful',
#   'during',
#   'the',
#   'day',
#   'and',
#   'it',
#   'one',
#   'of',
#   'the',
#   'best',
#   'sunset',
#   'spot',
#   'in',
#   'the',
#   'evening',
#   'The',
#   'area',
#   'is',
#   'quite',
#   'busy',
#   'because',
#   'of',
#   'the',
#   'popularity',
#   'of',
#   'the',
#   'beach',
#   'We',
#   'were',
#   'staying',
#   'on',
#   'the',
#   'completely',
#   'opposite',
#   'side',
#   'of',
#   'the',
#   'island',
#   'but',
#   'it',
#   'wa',
#   'worth',
#   'the',
#   'long',
#   'drive',
#   'to',
#   'hang',
#   'out',
#   'there',
#   'for',
#   'day'],
#  ['Nice',
#   'view',
#   'nice',
#   'place',
#   'to',
#   'take',
#   'picture',
#   'not',
#   'lot',
#   'of',
#   'beach',
#   'front',
#   'to',
#   'relax',
#   'or',
#   'swim',
#   'Most',
#   'of',
#   'the',
#   'area',
#   'people',
#   'relax',
#   'and',
#   'sunbath',
#   'are',
#   'away',
#   'from',
#   'the',
#   'beach',
#   'since',
#   'most',
#   'of',
#   'the',
#   'coast',
#   'ha',
#   'lava',
#   'rock',
#   'Fun',
#   'place',
#   'for',
#   'kid',
#   'to',
#   'find',
#   'stuff',
#   'in',
#   'the',
#   'rock'],
#  ['Don',
#   'judge',
#   'know',
#   'it',
#   'wa',
#   'cold',
#   'and',
#   'all',
#   'but',
#   'we',
#   'wanted',
#   'to',
#   'do',
#   'something',
#   'cool',
#   'Beach',
#   'in',
#   'the',
#   'winter',
#   'LOL',
#   'XP'],
#  ['Beautiful',
#   'beach',
#   'in',
#   'hip',
#   'area',
#   'Plenty',
#   'of',
#   'rental',
#   'available',
#   'good',
#   'food',
#   'and',
#   'perfect',
#   'place',
#   'for',
#   'family',
#   'fun'],
#  ['Very',
#   'good',
#   'for',
#   'relax',
#   'and',
#   'some',
#   'swimming',
#   'water',
#   'in',
#   'September',
#   'wa',
#   'not',
#   'too',
#   'hot',
#   'If',
#   'you',
#   'had',
#   'time',
#   'visit',
#   'nice',
#   'small',
#   'island',
#   'ahead',
#   'very',
#   'recommended'],
#  ['Wonderful',
#   'beach',
#   'in',
#   'Jeju',
#   'island',
#   'Very',
#   'clear',
#   'water',
#   'Amazing',
#   'color',
#   'and',
#   'good',
#   'vibe',
#   'all',
#   'around',
#   'You',
#   'can',
#   'spend',
#   'here',
#   'one',
#   'day',
#   'to',
#   'have',
#   'relax',
#   'and',
#   'chill',
#   'out',
#   'And',
#   'If',
#   'you',
#   'want',
#   'you',
#   'can',
#   'walk',
#   'around',
#   'There',
#   'are',
#   'close',
#   'to',
#   'the',
#   'beach',
#   'lot',
#   'of',
#   'restaurant',
#   'and',
#   'caf챕s'],
#  ['The',
#   'beach',
#   'by',
#   'bus',
#   'is',
#   'easy',
#   'to',
#   'get',
#   'to',
#   'the',
#   'bus',
#   'stop',
#   'is',
#   'located',
#   'about',
#   'or',
#   'minute',
#   'away',
#   'the',
#   'beach',
#   'is',
#   'clean',
#   'and',
#   'the',
#   'water',
#   'is',
#   'lovely',
#   'and',
#   'blue'],
#  ['Car',
#   'parking',
#   'near',
#   'the',
#   'beach',
#   'is',
#   'nightmare',
#   'too',
#   'many',
#   'car',
#   'car',
#   'parked',
#   'improperly',
#   'but',
#   'at',
#   'least',
#   'it',
#   'wa',
#   'free',
#   'really',
#   'like',
#   'this',
#   'beach',
#   'a',
#   'it',
#   'wa',
#   'very',
#   'clean',
#   'although',
#   'there',
#   'were',
#   'lot',
#   'of',
#   'people',
#   'the',
#   'beach',
#   'can',
#   'easy',
#   'absorb',
#   'them',
#   'due',
#   'to',
#   'it',
#   'size',
#   'lot',
#   'of',
#   'cafe',
#   'and',
#   'coffee',
#   'shop',
#   'nearby',
#   'arrived',
#   'at',
#   'low',
#   'tide',
#   'and',
#   'it',
#   'wasn',
#   'suitable',
#   'for',
#   'swimmer',
#   'a',
#   'the',
#   'deepest',
#   'point',
#   'next',
#   'to',
#   'shark',
#   'net',
#   'wa',
#   'only',
#   'up',
#   'to',
#   'my',
#   'thigh',
#   'So',
#   'wa',
#   'disappointed',
#   'by',
#   'that',
#   'maybe',
#   'it',
#   'lot',
#   'better',
#   'during',
#   'high',
#   'tide',
#   'Another',
#   'negative',
#   'is',
#   'you',
#   'have',
#   'to',
#   'pay',
#   'to',
#   'use',
#   'the',
#   'SHOWERS',
#   '3000w',
#   'for',
#   'adult',
#   'and',
#   '2000w',
#   'child',
#   'shower',
#   'gel',
#   'and',
#   'shampoo',
#   'is',
#   'available',
#   'for',
#   'price'],
#  ['Water',
#   'wa',
#   'very',
#   'clear',
#   'and',
#   'sand',
#   'wa',
#   'clean',
#   'There',
#   'are',
#   'some',
#   'shop',
#   'on',
#   'the',
#   'beach',
#   'and',
#   'toilet',
#   'facility',
#   'close',
#   'by',
#   'Plenty',
#   'of',
#   'eating',
#   'place',
#   'around',
#   'the',
#   'area',
#   'too',
#   'nice',
#   'beach',
#   'to',
#   'spent',
#   'day',
#   'or',
#   'just',
#   'little',
#   'while',
#   'There',
#   'are',
#   'people',
#   'firing',
#   'firework',
#   'at',
#   'night',
#   'So',
#   'if',
#   'you',
#   'happen',
#   'to',
#   'be',
#   'there',
#   'when',
#   'that',
#   'happen',
#   'you',
#   'are',
#   'in',
#   'for',
#   'some',
#   'light',
#   'show'],
#  ['My',
#   'girlfriend',
#   'and',
#   'went',
#   'for',
#   'walk',
#   'here',
#   'and',
#   'sat',
#   'on',
#   'bench',
#   'to',
#   'watch',
#   'the',
#   'sun',
#   'go',
#   'down',
#   'It',
#   'wa',
#   'picturesque',
#   'setting',
#   'which',
#   'we',
#   'enjoyed',
#   'There',
#   'are',
#   'hundred',
#   'of',
#   'little',
#   'rock',
#   'pile',
#   'people',
#   'have',
#   'built',
#   'which',
#   'recommend',
#   'seeing',
#   'We',
#   'were',
#   'not',
#   'there',
#   'to',
#   'swim',
#   'but',
#   'the',
#   'water',
#   'felt',
#   'good',
#   'on',
#   'the',
#   'foot',
#   'Shane',
#   'Jill'],
#  ['We',
#   'visited',
#   'this',
#   'beautiful',
#   'beach',
#   'a',
#   'part',
#   'of',
#   'the',
#   'Western',
#   'Discovery',
#   'Tour',
#   'organized',
#   'by',
#   'Yeha',
#   'Bus',
#   'tour',
#   'so',
#   'we',
#   'were',
#   'only',
#   'given',
#   'limited',
#   'time',
#   'to',
#   'experience',
#   'the',
#   'beach',
#   'We',
#   'visited',
#   'during',
#   'the',
#   'early',
#   'day',
#   'of',
#   'spring',
#   'so',
#   'it',
#   'wa',
#   'still',
#   'quite',
#   'chilly',
#   'The',
#   'view',
#   'of',
#   'the',
#   'beach',
#   'are',
#   'undeniably',
#   'breathtaking',
#   'Ten',
#   'minute',
#   'is',
#   'more',
#   'than',
#   'enough',
#   'to',
#   'get',
#   'in',
#   'those',
#   'nice',
#   'shot'],
#  ['We',
#   'go',
#   'to',
#   'Hyeopjae',
#   'beach',
#   'whenever',
#   'in',
#   'Jeju',
#   'lovely',
#   'sand',
#   'good',
#   'safe',
#   'swimming',
#   'great',
#   'rock',
#   'to',
#   'climb',
#   'over',
#   'the',
#   'grandkids',
#   'love',
#   'it'],
#  ['Of',
#   'the',
#   'beach',
#   'we',
#   'visited',
#   'in',
#   'Jeju',
#   'this',
#   'one',
#   'wa',
#   'disappointing',
#   'The',
#   'ground',
#   'sand',
#   'is',
#   'covered',
#   'in',
#   'matting',
#   'likely',
#   'to',
#   'prevent',
#   'erosion',
#   'and',
#   'the',
#   'area',
#   'seemed',
#   'little',
#   'untidy'],
#  ['The',
#   'beach',
#   'is',
#   'nice',
#   'with',
#   'combination',
#   'of',
#   'sand',
#   'and',
#   'rock',
#   'Korean',
#   'people',
#   'use',
#   'EVERY',
#   'available',
#   'inch',
#   'of',
#   'land',
#   'They',
#   'pull',
#   'their',
#   'trailer',
#   'and',
#   'car',
#   'right',
#   'to',
#   'the',
#   'edge',
#   'of',
#   'the',
#   'beach',
#   'and',
#   'set',
#   'up',
#   'camp',
#   'Don',
#   'understand',
#   'why',
#   'swimming',
#   'wasn',
#   'allowed',
#   'People',
#   'were',
#   'wading',
#   'in',
#   'the',
#   'water'],
#  ['Visited',
#   'Monsanto',
#   'cafe',
#   'and',
#   'found',
#   'there',
#   'are',
#   'afew',
#   'other',
#   'cafe',
#   'there',
#   'next',
#   'to',
#   'each',
#   'other',
#   'It',
#   'must',
#   'go',
#   'if',
#   'you',
#   'love',
#   'beautiful',
#   'beach'],
#  ['The',
#   'colour',
#   'of',
#   'Hyeopjae',
#   'beach',
#   'is',
#   'real',
#   'it',
#   'is',
#   'not',
#   'edited',
#   'It',
#   'wa',
#   'very',
#   'beautiful',
#   'the',
#   'black',
#   'coral',
#   'make',
#   'it',
#   'perfect'],
#  ['One',
#   'of',
#   'the',
#   'best',
#   'beach',
#   'in',
#   'Jeju',
#   'we',
#   'loved',
#   'this',
#   'place',
#   'for',
#   'it',
#   'cobalt',
#   'colored',
#   'crystal',
#   'clear',
#   'water',
#   'and',
#   'fine',
#   'white',
#   'sand',
#   'and',
#   'the',
#   'view',
#   'of',
#   'Mount',
#   'Hallasan',
#   'Our',
#   'kid',
#   'enjoyed',
#   'playing',
#   'in',
#   'water',
#   'and',
#   'collecting',
#   'seashell',
#   'while',
#   'we',
#   'enjoyed',
#   'walking',
#   'along',
#   'the',
#   'shore',
#   'Food',
#   'stall',
#   'shop',
#   'umbrella',
#   'rental',
#   'are',
#   'available'],
#  ['Beautiful',
#   'sand',
#   'beach',
#   'Couldn',
#   'swim',
#   'coz',
#   'we',
#   'visited',
#   'during',
#   'the',
#   'autumn',
#   'It',
#   'll',
#   'be',
#   'too',
#   'cold',
#   'for',
#   'u',
#   'to',
#   'swim',
#   'It',
#   'amazing',
#   'to',
#   'see',
#   'lava',
#   'rock',
#   'stacked',
#   'at',
#   'one',
#   'corner',
#   'of',
#   'the',
#   'beach',
#   'We',
#   'had',
#   'very',
#   'nice',
#   'lunch',
#   'nearby',
#   'Love',
#   'their',
#   'seafood',
#   'noodle',
#   'soup',
#   'but',
#   'forgot',
#   'the',
#   'name',
#   'of',
#   'the',
#   'restaurant',
#   'Sorry',
#   'guy'],
#  ['We',
#   'are',
#   'so',
#   'glad',
#   'we',
#   'managed',
#   'to',
#   'catch',
#   'such',
#   'beautiful',
#   'sunset',
#   'here',
#   'Had',
#   'cuppa',
#   'latte',
#   'at',
#   'the',
#   'cafe',
#   'There',
#   'are',
#   'plenty',
#   'of',
#   'cafe',
#   'and',
#   'restaurant',
#   'around',
#   'Plenty',
#   'of',
#   'parking',
#   'lot',
#   'too'],
#  ['Wonderful',
#   'beach',
#   'stayed',
#   'short',
#   'while',
#   'and',
#   'had',
#   'coffee',
#   'it',
#   'great',
#   'place',
#   'to',
#   'relax',
#   'go',
#   'early',
#   'avoid',
#   'the',
#   'crowd'],
#  ['It',
#   'beautiful',
#   'but',
#   'really',
#   'cold',
#   'dipped',
#   'my',
#   'foot',
#   'in',
#   'the',
#   'water',
#   'because',
#   'didnt',
#   'see',
#   'it',
#   'The',
#   'water',
#   'wa',
#   'so',
#   'clear',
#   'the',
#   'sunset',
#   'is',
#   'soooo',
#   'beautiful'],
#  ['Went',
#   'to',
#   'hyeopjae',
#   'beach',
#   'just',
#   'to',
#   'try',
#   'swimming',
#   'while',
#   'wa',
#   'in',
#   'Jeju',
#   'Rented',
#   'car',
#   'and',
#   'drove',
#   'there',
#   'thought',
#   'that',
#   'parking',
#   'wa',
#   'gonna',
#   'be',
#   'challenge',
#   'but',
#   'managed',
#   'to',
#   'get',
#   'one',
#   'in',
#   'mere',
#   'minute',
#   'Mum',
#   'didnt',
#   'swim',
#   'so',
#   'we',
#   'rented',
#   'an',
#   'umbrella',
#   'mat',
#   'for',
#   'her',
#   'to',
#   'wait',
#   'at',
#   'Cost',
#   'u',
#   '15K',
#   'won',
#   'Not',
#   'sure',
#   'if',
#   'it',
#   'wa',
#   'cheap',
#   'or',
#   'expensive',
#   'They',
#   'guy',
#   'attending',
#   'to',
#   'the',
#   'rental',
#   'didn',
#   'speak',
#   'english',
#   'thank',
#   'God',
#   'for',
#   'local',
#   'young',
#   'chap',
#   'who',
#   'helped',
#   'u',
#   'translate',
#   'Loved',
#   'the',
#   'vibe',
#   'of',
#   'the',
#   'beach',
#   'everyone',
#   'there',
#   'wa',
#   'enjoying',
#   'the',
#   'wave',
#   'Where',
#   'from',
#   'our',
#   'sea',
#   'is',
#   'not',
#   'a',
#   'rough',
#   'so',
#   'it',
#   'wa',
#   'really',
#   'different',
#   'to',
#   'see',
#   'everyone',
#   'in',
#   'their',
#   'floaties',
#   'waiting',
#   'for',
#   'wave',
#   'to',
#   'hit',
#   'them'],
#  ['If',
#   'you',
#   'wanna',
#   'experience',
#   'to',
#   'swim',
#   'in',
#   'the',
#   'ocean',
#   'and',
#   'in',
#   'the',
#   'volcanic',
#   'water',
#   'this',
#   'is',
#   'the',
#   'place',
#   'You',
#   'hire',
#   'the',
#   'spot',
#   'for',
#   'couple',
#   'of',
#   'hour',
#   'and',
#   'until'],
#  ['This',
#   'beach',
#   'is',
#   'adjecent',
#   'to',
#   'GeumNeung',
#   'Beach',
#   'you',
#   'can',
#   'walk',
#   'between',
#   'them',
#   'Hallim',
#   'Park',
#   'is',
#   'also',
#   'next',
#   'to',
#   'it',
#   'all',
#   'are',
#   'walkable',
#   'from',
#   'each',
#   'other',
#   'There',
#   'are',
#   'plenty',
#   'of',
#   'shop',
#   'and',
#   'umbrella',
#   'rental',
#   'etc',
#   'Camping',
#   'is',
#   'avaiable',
#   'at',
#   'the',
#   'next',
#   'door',
#   'beach',
#   'Some',
#   'area',
#   'are',
#   'not',
#   'for',
#   'swimming',
#   'due',
#   'to',
#   'strong',
#   'current',
#   'Lovely',
#   'view',
#   'of',
#   'nearby',
#   'island',
#   'You',
#   'can',
#   'take',
#   'the',
#   '202',
#   'bus',
#   'from',
#   'the',
#   'day',
#   'market',
#   'near',
#   'the',
#   'airport',
#   'Takes',
#   'about',
#   'an',
#   'hour'],
#  ['stayed',
#   'here',
#   'for',
#   'couple',
#   'of',
#   'hour',
#   'swam',
#   'enjoyed',
#   'the',
#   'sun',
#   'discussed',
#   'the',
#   'Jeju',
#   'rout',
#   'with',
#   'young',
#   'traveller',
#   'We',
#   'laughed',
#   'lot',
#   'practiced',
#   'language',
#   'Black',
#   'lava',
#   'beach',
#   'is',
#   'happy',
#   'noisy',
#   'place'],
#  ['This',
#   'beach',
#   'is',
#   'good',
#   'and',
#   'definitely',
#   'worth',
#   'visiting',
#   'Admittedly',
#   'it',
#   'didn',
#   'live',
#   'up',
#   'to',
#   'what',
#   'had',
#   'expected',
#   'when',
#   'heard',
#   'beach',
#   'however',
#   'think',
#   'this',
#   'is',
#   'due',
#   'to',
#   'me',
#   'living',
#   'near',
#   'the',
#   'Gold',
#   'Coast',
#   'Sunshine',
#   'Coast',
#   'in',
#   'Australia',
#   'Very',
#   'good',
#   'must',
#   'see',
#   'of',
#   'Jeju'],
#  ['Stayed',
#   'by',
#   'Hyeopjae',
#   'beach',
#   'two',
#   'night',
#   'wish',
#   'we',
#   'stayed',
#   'longer',
#   'Lovely',
#   'place',
#   'with',
#   'real',
#   'local',
#   'feeling',
#   'many',
#   'caf챕s',
#   'and',
#   'restaurant',
#   'around',
#   'Large',
#   'and',
#   'free',
#   'car',
#   'park',
#   'Don',
#   'miss',
#   'the',
#   'beer',
#   'battered',
#   'chicken',
#   'with',
#   'beer',
#   'by',
#   'the',
#   'walk',
#   'down',
#   'to',
#   'the',
#   'beach',
#   'opposite',
#   'to',
#   'the',
#   'foot',
#   'cleaning',
#   'bath'],
#  ['We',
#   'had',
#   'much',
#   'better',
#   'time',
#   'here',
#   'than',
#   'at',
#   'Hamdeok',
#   'Beach',
#   'The',
#   'water',
#   'wa',
#   'much',
#   'more',
#   'shallow',
#   'more',
#   'friendly',
#   'for',
#   'swimmer',
#   'le',
#   'seaweed',
#   'at',
#   'low',
#   'tide',
#   'area',
#   'too',
#   'The',
#   'water',
#   'wa',
#   'clean',
#   'and',
#   'the',
#   'cafe',
#   'nearby',
#   'were',
#   'cute',
#   'too'],
#  ['This',
#   'beach',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'beariful',
#   'beach',
#   'in',
#   'Jeju',
#   'with',
#   'it',
#   'white',
#   'sand',
#   'and',
#   'really',
#   'good',
#   'restaurant',
#   'and',
#   'coffeeshops',
#   'nearby',
#   'Really',
#   'recomendable',
#   'to',
#   'go'],
#  ['This',
#   'stretch',
#   'of',
#   'beach',
#   'is',
#   'very',
#   'near',
#   'Hallim',
#   'park',
#   'We',
#   'happened',
#   'to',
#   'drive',
#   'by',
#   'and',
#   'stopped',
#   'for',
#   'photo',
#   'taking',
#   'There',
#   'are',
#   'few',
#   'restaurant',
#   'cafe',
#   'around',
#   'the',
#   'area',
#   'and',
#   'convenient',
#   'store',
#   'The',
#   'sea',
#   'is',
#   'clear',
#   'and',
#   'there',
#   'were',
#   'lot',
#   'of',
#   'people',
#   'lazing',
#   'by',
#   'the',
#   'beach',
#   'Was',
#   'short',
#   'stopover',
#   'for',
#   'my',
#   'family',
#   'nice',
#   'scenery',
#   'no',
#   'harm',
#   'stopping',
#   'by',
#   'for',
#   'quick',
#   'foto',
#   'shoot'],
#  ['visited',
#   'different',
#   'beach',
#   'in',
#   'Jeju',
#   'They',
#   'all',
#   'had',
#   'their',
#   'own',
#   'charm',
#   'but',
#   'for',
#   'popularity',
#   'go',
#   'to',
#   'Hyeopjae',
#   'Beach',
#   'becaue',
#   'of',
#   'good',
#   'size',
#   'and',
#   'fantastic',
#   'photogenic',
#   'view',
#   'If',
#   'you',
#   'want',
#   'calmer',
#   'smaller',
#   'le',
#   'crowded',
#   'and',
#   'le',
#   'windy',
#   'beach',
#   'there',
#   'is',
#   'Kumnyoung',
#   'beach',
#   'right',
#   'next',
#   'to',
#   'Hyeopjae',
#   'beach',
#   'It',
#   'is',
#   'good',
#   'for',
#   'younger',
#   'child',
#   'to',
#   'play',
#   'Hyeopjae',
#   'beach',
#   'wa',
#   'quite',
#   'windy',
#   'and',
#   'cold',
#   'Of',
#   'course',
#   'Summer',
#   'time',
#   'would',
#   'be',
#   'different',
#   'story',
#   'wa',
#   'looking',
#   'forward',
#   'to',
#   'riding',
#   'transparent',
#   'kayak',
#   'but',
#   'it',
#   'wa',
#   'not',
#   'operating',
#   'in',
#   'Apr',
#   'There',
#   'wa',
#   'number',
#   'on',
#   'banner',
#   'but',
#   'no',
#   'one',
#   'answered'],
#  ['and',
#   'my',
#   'wife',
#   'went',
#   'to',
#   'this',
#   'beach',
#   'a',
#   'this',
#   'beach',
#   'wa',
#   'the',
#   'first',
#   'pitstop',
#   'for',
#   'west',
#   'package',
#   'in',
#   'Yeha',
#   'Tour',
#   'The',
#   'place',
#   'wa',
#   'very',
#   'cold',
#   'since',
#   'we',
#   'visited',
#   'during',
#   'winter',
#   'season',
#   'But',
#   'the',
#   'scenery',
#   'wa',
#   'very',
#   'beautiful',
#   'and',
#   'lovely',
#   'Seriously',
#   'recommended',
#   'for',
#   'the',
#   'honeymoon',
#   'lover'],
#  ['The',
#   'tourist',
#   'industry',
#   'is',
#   'creative',
#   'So',
#   'they',
#   'discovered',
#   'sandy',
#   'patch',
#   'on',
#   'the',
#   'Island',
#   'and',
#   'made',
#   'it',
#   'highlight',
#   'for',
#   'an',
#   'excursion',
#   'to',
#   'the',
#   'Western',
#   'part',
#   'of',
#   'the',
#   'Island',
#   'After',
#   'one',
#   'picture',
#   'you',
#   'can',
#   'leave',
#   'The',
#   'sand',
#   'is',
#   'nice',
#   'however',
#   'took',
#   'sample'],
#  ['Too',
#   'bad',
#   'we',
#   'went',
#   'in',
#   'fall',
#   'would',
#   'have',
#   'so',
#   'wanted',
#   'to',
#   'go',
#   'in',
#   'those',
#   'beautiful',
#   'turquoise',
#   'water',
#   'But',
#   'we',
#   'sat',
#   'in',
#   'front',
#   'of',
#   'the',
#   'beach',
#   'and',
#   'didnt',
#   'realize',
#   'how',
#   'much',
#   'time',
#   'had',
#   'passed',
#   'by',
#   'The',
#   'colour',
#   'are',
#   'impressive',
#   'My',
#   'favorite',
#   'beach',
#   'in',
#   'Jeju'],
#  ['Very',
#   'beautiful',
#   'beach',
#   'although',
#   'one',
#   'ha',
#   'to',
#   'pay',
#   'large',
#   'amount',
#   'for',
#   'spot',
#   'with',
#   'an',
#   'umbrella',
#   'on',
#   'the',
#   'main',
#   'beach',
#   'You',
#   'can',
#   'however',
#   'walk',
#   'just',
#   'bit',
#   'further',
#   'and',
#   'find',
#   'another',
#   'beach',
#   'Beautiful',
#   'beach',
#   'with',
#   'clear',
#   'water',
#   'It',
#   'can',
#   'become',
#   'crowded',
#   'in',
#   'summer',
#   'over',
#   'the',
#   'weekend'],
#  ['If',
#   'you',
#   'are',
#   'coming',
#   'from',
#   'country',
#   'with',
#   'lot',
#   'of',
#   'island',
#   'and',
#   'beach',
#   'like',
#   'the',
#   'Philippines',
#   'then',
#   'this',
#   'place',
#   'can',
#   'be',
#   'omitted',
#   'from',
#   'your',
#   'itinerary',
#   'Food',
#   'and',
#   'drink',
#   'are',
#   'readily',
#   'available',
#   'in',
#   'this',
#   'area',
#   'but',
#   'it',
#   'wa',
#   'too',
#   'touristy',
#   'for',
#   'me'],
#  ['Love',
#   'this',
#   'beach',
#   'Sand',
#   'wa',
#   'soft',
#   'and',
#   'the',
#   'sea',
#   'wa',
#   'beautiful',
#   'We',
#   'walked',
#   'to',
#   'the',
#   'extreme',
#   'left',
#   'and',
#   'it',
#   'wa',
#   'peaceful',
#   'quiet',
#   'and',
#   'secluded'],
#  ['This',
#   'beach',
#   'wa',
#   'really',
#   'clean',
#   'and',
#   'had',
#   'many',
#   'food',
#   'facility',
#   'available',
#   'There',
#   'wa',
#   'free',
#   'parking',
#   'We',
#   'did',
#   'come',
#   'in',
#   'October',
#   'but',
#   'could',
#   'definitely',
#   'see',
#   'this',
#   'place',
#   'full',
#   'of',
#   'people',
#   'in',
#   'the',
#   'summer',
#   'It',
#   'is',
#   'relatively',
#   'close',
#   'to',
#   'Jeju',
#   'city',
#   'and',
#   'ha',
#   'quite',
#   'bit',
#   'to',
#   'offer'],
#  ['Worth',
#   'visit',
#   'if',
#   'you',
#   'are',
#   'beach',
#   'person',
#   'lot',
#   'of',
#   'people',
#   'Plenty',
#   'of',
#   'food',
#   'booth',
#   'and',
#   'shop',
#   'close',
#   'by',
#   'lot',
#   'of',
#   'gimmick',
#   'to',
#   'buy',
#   'to',
#   'include',
#   'in',
#   'your',
#   'day',
#   'Water',
#   'wa',
#   'okay',
#   'typical',
#   'sand',
#   'in',
#   'the',
#   'pant',
#   'type',
#   'of',
#   'thing'],
#  ['White',
#   'sand',
#   'clear',
#   'water',
#   'View',
#   'of',
#   'several',
#   'island',
#   'Family',
#   'beach',
#   'Easy',
#   'to',
#   'get',
#   'to',
#   'great',
#   'to',
#   'walk',
#   'along',
#   'the',
#   'water',
#   'edge'],
#  ['It',
#   'tourist',
#   'packed',
#   'beach',
#   'in',
#   'the',
#   'summer',
#   'time',
#   'It',
#   'quite',
#   'expansive',
#   'so',
#   'you',
#   'can',
#   'go',
#   'to',
#   'your',
#   'own',
#   'spot',
#   'thats',
#   'semi',
#   'private',
#   'Recommend',
#   'you',
#   'to',
#   'travel',
#   'outside',
#   'the',
#   'vacation',
#   'period',
#   'unless',
#   'you',
#   'love',
#   'swarm',
#   'of',
#   'family',
#   'with',
#   'child'],
#  ['We',
#   'have',
#   'visited',
#   'this',
#   'beach',
#   'on',
#   'our',
#   'first',
#   'day',
#   'in',
#   'Jeju',
#   'island',
#   'As',
#   'soon',
#   'a',
#   'we',
#   'walked',
#   'in',
#   'we',
#   'felt',
#   'so',
#   'happy',
#   'to',
#   'see',
#   'this',
#   'beautiful',
#   'beach',
#   'It',
#   'wa',
#   'beginning',
#   'of',
#   'September',
#   'it',
#   'wa',
#   'hot',
#   'but',
#   'a',
#   'soon',
#   'a',
#   'we',
#   'went',
#   'to',
#   'beach',
#   'we',
#   'almost',
#   'got',
#   'frozen',
#   'due',
#   'to',
#   'strong',
#   'wind',
#   'Sand',
#   'is',
#   'white',
#   'and',
#   'when',
#   'combined',
#   'with',
#   'clear',
#   'sky',
#   'water',
#   'appears',
#   'Caribbean',
#   'blue',
#   'it',
#   'wa',
#   'difficult',
#   'to',
#   'find',
#   'place',
#   'to',
#   'sit',
#   'a',
#   'it',
#   'wa',
#   'overcrowded',
#   'We',
#   'asked',
#   'lady',
#   'in',
#   'local',
#   'shop',
#   'to',
#   'keep',
#   'our',
#   'belonging',
#   'for',
#   'u',
#   'while',
#   'we',
#   'are',
#   'swimming',
#   'she',
#   'wa',
#   'very',
#   'kind',
#   'and',
#   'didn',
#   'ask',
#   'any',
#   'money',
#   'from',
#   'u',
#   'We',
#   'also',
#   'met',
#   'sunset',
#   'on',
#   'this',
#   'beach',
#   'It',
#   'wa',
#   'gorgeous',
#   'Tip',
#   'Take',
#   'windproof',
#   'jacket',
#   'with',
#   'hood',
#   'of',
#   'you',
#   'cannot',
#   'stand',
#   'for',
#   'wind',
#   'for',
#   'long',
#   'time',
#   'Renting',
#   'place',
#   'on',
#   'beach',
#   'with',
#   'umbrella',
#   'cost',
#   '10',
#   '000KRW',
#   'Renting',
#   'some',
#   'inflatable',
#   'toy',
#   'flamingo',
#   'for',
#   'example',
#   'is',
#   'also',
#   '10',
#   '000',
#   'Life',
#   'vest',
#   'goggles',
#   'rent',
#   'is',
#   'also',
#   '10',
#   '000',
#   'And',
#   'you',
#   'won',
#   'see',
#   'any',
#   'price',
#   'tag',
#   'around',
#   'kind',
#   'of',
#   'weird',
#   'Food',
#   'around',
#   'Chinese',
#   'restaurant',
#   'across',
#   'the',
#   'street',
#   'serf',
#   'nice',
#   'jajamyun',
#   'noodle',
#   'for',
#   'or',
#   '000',
#   'KRW',
#   'can',
#   'recommend',
#   'it',
#   'Drinks',
#   'cafe',
#   'bene',
#   'with',
#   'gorgeous',
#   'view',
#   'Average',
#   'coffee',
#   'Good',
#   'bagel',
#   'with',
#   'crab',
#   'meat'],
#  ['Even',
#   'during',
#   'slightly',
#   'overcast',
#   'condition',
#   'this',
#   'wa',
#   'very',
#   'pleasant',
#   'stroll',
#   'People',
#   'enjoying',
#   'the',
#   'very',
#   'blue',
#   'water',
#   'and',
#   'peering',
#   'into',
#   'tide',
#   'pool',
#   'Progressed',
#   'from',
#   'lava',
#   'stone',
#   'to',
#   'smooth',
#   'sandy',
#   'beach'],
#  ['Fish',
#   'and',
#   'chip',
#   'shop',
#   'with',
#   'Aussie',
#   'beer',
#   'wine',
#   'and',
#   'African',
#   'Savanna',
#   'cider',
#   'Many',
#   'other',
#   'eatery',
#   'nearby'],
#  ['We',
#   'originally',
#   'got',
#   'the',
#   'bus',
#   'here',
#   'to',
#   'go',
#   'to',
#   'hallim',
#   'park',
#   'we',
#   'noticed',
#   'this',
#   'beautiful',
#   'beach',
#   'and',
#   'decided',
#   'to',
#   'check',
#   'it',
#   'out',
#   'anyway',
#   'we',
#   'ended',
#   'up',
#   'staying',
#   'here',
#   'all',
#   'day',
#   'Was',
#   'so',
#   'nice',
#   'to',
#   'be',
#   'on',
#   'such',
#   'soft',
#   'yellow',
#   'sand',
#   'with',
#   'clear',
#   'water',
#   'There',
#   'wa',
#   'quite',
#   'few',
#   'family',
#   'with',
#   'young',
#   'child',
#   'which',
#   'wa',
#   'nice',
#   'to',
#   'see',
#   'all',
#   'the',
#   'child',
#   'playing',
#   'Unfortunately',
#   'there',
#   'wa',
#   'digger',
#   'truck',
#   'digging',
#   'the',
#   'sand',
#   'while',
#   'we',
#   'were',
#   'there',
#   'for',
#   'few',
#   'hour',
#   'and',
#   'man',
#   'kept',
#   'blowing',
#   'his',
#   'whistle',
#   'at',
#   'everyone',
#   'walking',
#   'near',
#   'the',
#   'truck',
#   'if',
#   'it',
#   'wasnt',
#   'for',
#   'this',
#   'it',
#   'would',
#   'have',
#   'been',
#   'excellent',
#   'Theres',
#   'shop',
#   'and',
#   'restaurant',
#   'close',
#   'by',
#   'and',
#   'toilet',
#   'block',
#   'that',
#   'provide',
#   'flowing',
#   'water',
#   'to',
#   'wash',
#   'off',
#   'but',
#   'this',
#   'is',
#   'cut',
#   'off',
#   'around',
#   'or',
#   'pm',
#   'Sunset',
#   'here',
#   'wa',
#   'amazing'],
#  ['Very',
#   'lovely',
#   'and',
#   'shallow',
#   'beach',
#   'so',
#   'good',
#   'for',
#   'snorkeling',
#   'And',
#   'actually',
#   'quite',
#   'famous',
#   'for',
#   'snorkeling',
#   'already',
#   'You',
#   'will',
#   'see',
#   'lot',
#   'of',
#   'young',
#   'people',
#   'in',
#   'summer',
#   'But',
#   'it',
#   'ha',
#   'also',
#   'great',
#   'scenery',
#   'in',
#   'winter',
#   'too'],
#  ['This',
#   'is',
#   'not',
#   'your',
#   'traditional',
#   'beach',
#   'It',
#   'is',
#   'quite',
#   'rocky',
#   'and',
#   'ha',
#   'limited',
#   'sand',
#   'however',
#   'really',
#   'spectacular',
#   'geographical',
#   'feature',
#   'to',
#   'see',
#   'here',
#   'Lots',
#   'of',
#   'restaurant',
#   'nearby',
#   'and',
#   'also',
#   'you',
#   'can',
#   'visit',
#   'Hallim',
#   'park',
#   'for',
#   'few',
#   'hour',
#   'Think',
#   'this',
#   'beach',
#   'would',
#   'have',
#   'been',
#   'better',
#   'in',
#   'the',
#   'height',
#   'of',
#   'summer',
#   'July',
#   'August'],
#  ['This',
#   'is',
#   'great',
#   'beach',
#   'with',
#   'the',
#   'most',
#   'beautiful',
#   'water',
#   'on',
#   'Jeju',
#   'The',
#   'water',
#   'are',
#   'crystal',
#   'clear',
#   'and',
#   'the',
#   'color',
#   'is',
#   'picturesque',
#   'The',
#   'lava',
#   'rock',
#   'add',
#   'to',
#   'the',
#   'beauty',
#   'of',
#   'this',
#   'place'],
#  ['Spent',
#   'Sunday',
#   'morning',
#   'relaxing',
#   'on',
#   'this',
#   'magnificent',
#   'beach',
#   'Its',
#   'emerald',
#   'coloured',
#   'crystal',
#   'clear',
#   'water',
#   'and',
#   'fine',
#   'white',
#   'sand',
#   'laced',
#   'with',
#   'shell',
#   'that',
#   'make',
#   'it',
#   'glitter',
#   'magic',
#   'location',
#   'Cannot',
#   'wait',
#   'for',
#   'the',
#   'moon',
#   'to',
#   'appear',
#   'and',
#   'make',
#   'my',
#   'summer',
#   'complete',
#   'Walk',
#   'all',
#   'the',
#   'way',
#   'round',
#   'to',
#   'Geumneung',
#   'beach',
#   'and',
#   'enjoy',
#   'the',
#   'stroll',
#   'on',
#   'the',
#   'white',
#   'sand'],
#  ['We',
#   'are',
#   'staying',
#   'near',
#   'to',
#   'here',
#   'and',
#   'stopped',
#   'on',
#   'drive',
#   'through',
#   'Great',
#   'photo',
#   'opportunity',
#   'and',
#   'it',
#   'clean',
#   'with',
#   'white',
#   'sand',
#   'You',
#   'can',
#   'take',
#   'your',
#   'dog',
#   'here',
#   'also',
#   'which',
#   'is',
#   'great',
#   'and',
#   'there',
#   'is',
#   'camping',
#   'available',
#   'also',
#   'nice',
#   'little',
#   'stroll',
#   'around',
#   'the',
#   'point',
#   'and',
#   'there',
#   'is',
#   'another',
#   'little',
#   'cove',
#   'also',
#   'Not',
#   'very',
#   'busy',
#   'really',
#   'at',
#   'all',
#   'when',
#   'we',
#   'visited',
#   'No',
#   'swimming',
#   'sign',
#   'everywhere',
#   'but',
#   'great',
#   'for',
#   'paddling',
#   'and',
#   'taking',
#   'In',
#   'the',
#   'view',
#   'The',
#   'sea',
#   'is',
#   'beautifully',
#   'blue',
#   'in',
#   'the',
#   'shallow'],
#  ['This',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'beautiful',
#   'beach',
#   'in',
#   'Jeju',
#   'island',
#   'The',
#   'sea',
#   'wa',
#   'so',
#   'amazing',
#   'water',
#   'so',
#   'clear',
#   'and',
#   'having',
#   'light',
#   'ocean',
#   'blue',
#   'color',
#   'from',
#   'here',
#   'you',
#   'could',
#   'see',
#   'the',
#   'Biyangdo',
#   'island',
#   'very',
#   'close',
#   'However',
#   'it',
#   'wa',
#   'rather',
#   'cold',
#   'and',
#   'windy',
#   'for',
#   'u',
#   'so',
#   'we',
#   'could',
#   'not',
#   'swim',
#   'just',
#   'wandering',
#   'around',
#   'we',
#   'spent',
#   'around',
#   '2hrs',
#   'here',
#   'we',
#   'got',
#   'here',
#   'by',
#   'intercity',
#   'bus',
#   'no',
#   '702',
#   'about',
#   'hr',
#   'from',
#   'jeju',
#   'bus',
#   'terminal']]

# %%
from gensim.models import Phrases

# %%
bigram = Phrases(docs, min_count = 20)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)

# %%
# Remove rare and common tokens.
from gensim.corpora import Dictionary

# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.5)

# %%
# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 3
# Number of documents: 51

# %%
# Train LDA model.
from gensim.models import LdaModel

# Set training parameters.
num_topics = 10
chunksize = 2000
passes = 20
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make an index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)

# %%
top_topics = model.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -0.5430.
# [([(0.4148765, 'wa'), (0.33061308, 'it'), (0.25451046, 'is')],
#   -0.5198909714274872),
#  ([(0.9924305, 'wa'), (0.003784798, 'it'), (0.0037846419, 'is')],
#   -0.5198909714274872),
#  ([(0.41227996, 'wa'), (0.31741676, 'it'), (0.27030325, 'is')],
#   -0.5198909714274872),
#  ([(0.50985926, 'wa'), (0.31724948, 'it'), (0.1728913, 'is')],
#   -0.5198909714274872),
#  ([(0.33444205, 'wa'), (0.332779, 'is'), (0.33277893, 'it')],
#   -0.5340775095670859),
#  ([(0.9874884, 'it'), (0.0063760336, 'wa'), (0.006135636, 'is')],
#   -0.5347082256177651),
#  ([(0.992133, 'is'), (0.003971064, 'wa'), (0.0038958902, 'it')],
#   -0.5630813018969624),
#  ([(0.33333337, 'is'), (0.33333337, 'wa'), (0.3333333, 'it')],
#   -0.5630813018969624),
#  ([(0.3377673, 'is'), (0.33756214, 'it'), (0.32467052, 'wa')],
#   -0.5778985560872404),
#  ([(0.7393826, 'is'), (0.2467487, 'it'), (0.013868602, 'wa')],
#   -0.5778985560872404)]

# %%
# Out:
# 영어 불용어 갯수: 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
for idx, doc in enumerate(docs):
    result[idx] = []
    for token in doc:
        if token not in stop_words:
            result[idx].append(token)
            #result.append(token)

# %%
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
docs = [[lemmatizer.lemmatize(token) for token in doc] for doc in result]

# %%
docs
# Out:
# [['Hyeopjae',
#   'Beach',
#   'arguably',
#   'picturesque',
#   'beach',
#   'Jeju',
#   'The',
#   'emerald',
#   'colored',
#   'water',
#   'look',
#   'beautiful',
#   'day',
#   'one',
#   'best',
#   'sunset',
#   'spot',
#   'evening',
#   'The',
#   'area',
#   'quite',
#   'busy',
#   'popularity',
#   'beach',
#   'We',
#   'staying',
#   'completely',
#   'opposite',
#   'side',
#   'island',
#   'worth',
#   'long',
#   'drive',
#   'hang',
#   'day'],
#  ['Nice',
#   'view',
#   'nice',
#   'place',
#   'take',
#   'picture',
#   'lot',
#   'beach',
#   'front',
#   'relax',
#   'swim',
#   'Most',
#   'area',
#   'people',
#   'relax',
#   'sunbath',
#   'away',
#   'beach',
#   'since',
#   'coast',
#   'ha',
#   'lava',
#   'rock',
#   'Fun',
#   'place',
#   'kid',
#   'find',
#   'stuff',
#   'rock'],
#  ['Don',
#   'judge',
#   'know',
#   'cold',
#   'wanted',
#   'something',
#   'cool',
#   'Beach',
#   'winter',
#   'LOL',
#   'XP'],
#  ['Beautiful',
#   'beach',
#   'hip',
#   'area',
#   'Plenty',
#   'rental',
#   'available',
#   'good',
#   'food',
#   'perfect',
#   'place',
#   'family',
#   'fun'],
#  ['Very',
#   'good',
#   'relax',
#   'swimming',
#   'water',
#   'September',
#   'hot',
#   'If',
#   'time',
#   'visit',
#   'nice',
#   'small',
#   'island',
#   'ahead',
#   'recommended'],
#  ['Wonderful',
#   'beach',
#   'Jeju',
#   'island',
#   'Very',
#   'clear',
#   'water',
#   'Amazing',
#   'color',
#   'good',
#   'vibe',
#   'around',
#   'You',
#   'spend',
#   'one',
#   'day',
#   'relax',
#   'chill',
#   'And',
#   'If',
#   'want',
#   'walk',
#   'around',
#   'There',
#   'close',
#   'beach',
#   'lot',
#   'restaurant',
#   'caf챕s'],
#  ['The',
#   'beach',
#   'bus',
#   'easy',
#   'get',
#   'bus',
#   'stop',
#   'located',
#   'minute',
#   'away',
#   'beach',
#   'clean',
#   'water',
#   'lovely',
#   'blue'],
#  ['Car',
#   'parking',
#   'near',
#   'beach',
#   'nightmare',
#   'many',
#   'car',
#   'car',
#   'parked',
#   'improperly',
#   'least',
#   'free',
#   'really',
#   'like',
#   'beach',
#   'clean',
#   'although',
#   'lot',
#   'people',
#   'beach',
#   'easy',
#   'absorb',
#   'due',
#   'size',
#   'lot',
#   'cafe',
#   'coffee',
#   'shop',
#   'nearby',
#   'arrived',
#   'low',
#   'tide',
#   'suitable',
#   'swimmer',
#   'deepest',
#   'point',
#   'next',
#   'shark',
#   'net',
#   'thigh',
#   'So',
#   'disappointed',
#   'maybe',
#   'lot',
#   'better',
#   'high',
#   'tide',
#   'Another',
#   'negative',
#   'pay',
#   'use',
#   'SHOWERS',
#   '3000w',
#   'adult',
#   '2000w',
#   'child',
#   'shower',
#   'gel',
#   'shampoo',
#   'available',
#   'price'],
#  ['Water',
#   'clear',
#   'sand',
#   'clean',
#   'There',
#   'shop',
#   'beach',
#   'toilet',
#   'facility',
#   'close',
#   'Plenty',
#   'eating',
#   'place',
#   'around',
#   'area',
#   'nice',
#   'beach',
#   'spent',
#   'day',
#   'little',
#   'There',
#   'people',
#   'firing',
#   'firework',
#   'night',
#   'So',
#   'happen',
#   'happen',
#   'light',
#   'show'],
#  ['My',
#   'girlfriend',
#   'went',
#   'walk',
#   'sat',
#   'bench',
#   'watch',
#   'sun',
#   'go',
#   'It',
#   'picturesque',
#   'setting',
#   'enjoyed',
#   'There',
#   'hundred',
#   'little',
#   'rock',
#   'pile',
#   'people',
#   'built',
#   'recommend',
#   'seeing',
#   'We',
#   'swim',
#   'water',
#   'felt',
#   'good',
#   'foot',
#   'Shane',
#   'Jill'],
#  ['We',
#   'visited',
#   'beautiful',
#   'beach',
#   'part',
#   'Western',
#   'Discovery',
#   'Tour',
#   'organized',
#   'Yeha',
#   'Bus',
#   'tour',
#   'given',
#   'limited',
#   'time',
#   'experience',
#   'beach',
#   'We',
#   'visited',
#   'early',
#   'day',
#   'spring',
#   'still',
#   'quite',
#   'chilly',
#   'The',
#   'view',
#   'beach',
#   'undeniably',
#   'breathtaking',
#   'Ten',
#   'minute',
#   'enough',
#   'get',
#   'nice',
#   'shot'],
#  ['We',
#   'go',
#   'Hyeopjae',
#   'beach',
#   'whenever',
#   'Jeju',
#   'lovely',
#   'sand',
#   'good',
#   'safe',
#   'swimming',
#   'great',
#   'rock',
#   'climb',
#   'grandkids',
#   'love'],
#  ['Of',
#   'beach',
#   'visited',
#   'Jeju',
#   'one',
#   'disappointing',
#   'The',
#   'ground',
#   'sand',
#   'covered',
#   'matting',
#   'likely',
#   'prevent',
#   'erosion',
#   'area',
#   'seemed',
#   'little',
#   'untidy'],
#  ['The',
#   'beach',
#   'nice',
#   'combination',
#   'sand',
#   'rock',
#   'Korean',
#   'people',
#   'use',
#   'EVERY',
#   'available',
#   'inch',
#   'land',
#   'They',
#   'pull',
#   'trailer',
#   'car',
#   'right',
#   'edge',
#   'beach',
#   'set',
#   'camp',
#   'Don',
#   'understand',
#   'swimming',
#   'allowed',
#   'People',
#   'wading',
#   'water'],
#  ['Visited',
#   'Monsanto',
#   'cafe',
#   'found',
#   'afew',
#   'cafe',
#   'next',
#   'It',
#   'must',
#   'go',
#   'love',
#   'beautiful',
#   'beach'],
#  ['The',
#   'colour',
#   'Hyeopjae',
#   'beach',
#   'real',
#   'edited',
#   'It',
#   'beautiful',
#   'black',
#   'coral',
#   'make',
#   'perfect'],
#  ['One',
#   'best',
#   'beach',
#   'Jeju',
#   'loved',
#   'place',
#   'cobalt',
#   'colored',
#   'crystal',
#   'clear',
#   'water',
#   'fine',
#   'white',
#   'sand',
#   'view',
#   'Mount',
#   'Hallasan',
#   'Our',
#   'kid',
#   'enjoyed',
#   'playing',
#   'water',
#   'collecting',
#   'seashell',
#   'enjoyed',
#   'walking',
#   'along',
#   'shore',
#   'Food',
#   'stall',
#   'shop',
#   'umbrella',
#   'rental',
#   'available'],
#  ['Beautiful',
#   'sand',
#   'beach',
#   'Couldn',
#   'swim',
#   'coz',
#   'visited',
#   'autumn',
#   'It',
#   'cold',
#   'u',
#   'swim',
#   'It',
#   'amazing',
#   'see',
#   'lava',
#   'rock',
#   'stacked',
#   'one',
#   'corner',
#   'beach',
#   'We',
#   'nice',
#   'lunch',
#   'nearby',
#   'Love',
#   'seafood',
#   'noodle',
#   'soup',
#   'forgot',
#   'name',
#   'restaurant',
#   'Sorry',
#   'guy'],
#  ['We',
#   'glad',
#   'managed',
#   'catch',
#   'beautiful',
#   'sunset',
#   'Had',
#   'cuppa',
#   'latte',
#   'cafe',
#   'There',
#   'plenty',
#   'cafe',
#   'restaurant',
#   'around',
#   'Plenty',
#   'parking',
#   'lot'],
#  ['Wonderful',
#   'beach',
#   'stayed',
#   'short',
#   'coffee',
#   'great',
#   'place',
#   'relax',
#   'go',
#   'early',
#   'avoid',
#   'crowd'],
#  ['It',
#   'beautiful',
#   'really',
#   'cold',
#   'dipped',
#   'foot',
#   'water',
#   'didnt',
#   'see',
#   'The',
#   'water',
#   'clear',
#   'sunset',
#   'soooo',
#   'beautiful'],
#  ['Went',
#   'hyeopjae',
#   'beach',
#   'try',
#   'swimming',
#   'Jeju',
#   'Rented',
#   'car',
#   'drove',
#   'thought',
#   'parking',
#   'gonna',
#   'challenge',
#   'managed',
#   'get',
#   'one',
#   'mere',
#   'minute',
#   'Mum',
#   'didnt',
#   'swim',
#   'rented',
#   'umbrella',
#   'mat',
#   'wait',
#   'Cost',
#   'u',
#   '15K',
#   'Not',
#   'sure',
#   'cheap',
#   'expensive',
#   'They',
#   'guy',
#   'attending',
#   'rental',
#   'speak',
#   'english',
#   'thank',
#   'God',
#   'local',
#   'young',
#   'chap',
#   'helped',
#   'u',
#   'translate',
#   'Loved',
#   'vibe',
#   'beach',
#   'everyone',
#   'enjoying',
#   'wave',
#   'Where',
#   'sea',
#   'rough',
#   'really',
#   'different',
#   'see',
#   'everyone',
#   'floaties',
#   'waiting',
#   'wave',
#   'hit'],
#  ['If',
#   'wanna',
#   'experience',
#   'swim',
#   'ocean',
#   'volcanic',
#   'water',
#   'place',
#   'You',
#   'hire',
#   'spot',
#   'couple',
#   'hour'],
#  ['This',
#   'beach',
#   'adjecent',
#   'GeumNeung',
#   'Beach',
#   'walk',
#   'Hallim',
#   'Park',
#   'also',
#   'next',
#   'walkable',
#   'There',
#   'plenty',
#   'shop',
#   'umbrella',
#   'rental',
#   'etc',
#   'Camping',
#   'avaiable',
#   'next',
#   'door',
#   'beach',
#   'Some',
#   'area',
#   'swimming',
#   'due',
#   'strong',
#   'current',
#   'Lovely',
#   'view',
#   'nearby',
#   'island',
#   'You',
#   'take',
#   '202',
#   'bus',
#   'day',
#   'market',
#   'near',
#   'airport',
#   'Takes',
#   'hour'],
#  ['stayed',
#   'couple',
#   'hour',
#   'swam',
#   'enjoyed',
#   'sun',
#   'discussed',
#   'Jeju',
#   'rout',
#   'young',
#   'traveller',
#   'We',
#   'laughed',
#   'lot',
#   'practiced',
#   'language',
#   'Black',
#   'lava',
#   'beach',
#   'happy',
#   'noisy',
#   'place'],
#  ['This',
#   'beach',
#   'good',
#   'definitely',
#   'worth',
#   'visiting',
#   'Admittedly',
#   'live',
#   'expected',
#   'heard',
#   'beach',
#   'however',
#   'think',
#   'due',
#   'living',
#   'near',
#   'Gold',
#   'Coast',
#   'Sunshine',
#   'Coast',
#   'Australia',
#   'Very',
#   'good',
#   'must',
#   'see',
#   'Jeju'],
#  ['Stayed',
#   'Hyeopjae',
#   'beach',
#   'two',
#   'night',
#   'wish',
#   'stayed',
#   'longer',
#   'Lovely',
#   'place',
#   'real',
#   'local',
#   'feeling',
#   'many',
#   'caf챕s',
#   'restaurant',
#   'around',
#   'Large',
#   'free',
#   'car',
#   'park',
#   'Don',
#   'miss',
#   'beer',
#   'battered',
#   'chicken',
#   'beer',
#   'walk',
#   'beach',
#   'opposite',
#   'foot',
#   'cleaning',
#   'bath'],
#  ['We',
#   'much',
#   'better',
#   'time',
#   'Hamdeok',
#   'Beach',
#   'The',
#   'water',
#   'much',
#   'shallow',
#   'friendly',
#   'swimmer',
#   'le',
#   'seaweed',
#   'low',
#   'tide',
#   'area',
#   'The',
#   'water',
#   'clean',
#   'cafe',
#   'nearby',
#   'cute'],
#  ['This',
#   'beach',
#   'one',
#   'beariful',
#   'beach',
#   'Jeju',
#   'white',
#   'sand',
#   'really',
#   'good',
#   'restaurant',
#   'coffeeshops',
#   'nearby',
#   'Really',
#   'recomendable',
#   'go'],
#  ['This',
#   'stretch',
#   'beach',
#   'near',
#   'Hallim',
#   'park',
#   'We',
#   'happened',
#   'drive',
#   'stopped',
#   'photo',
#   'taking',
#   'There',
#   'restaurant',
#   'cafe',
#   'around',
#   'area',
#   'convenient',
#   'store',
#   'The',
#   'sea',
#   'clear',
#   'lot',
#   'people',
#   'lazing',
#   'beach',
#   'Was',
#   'short',
#   'stopover',
#   'family',
#   'nice',
#   'scenery',
#   'harm',
#   'stopping',
#   'quick',
#   'foto',
#   'shoot'],
#  ['visited',
#   'different',
#   'beach',
#   'Jeju',
#   'They',
#   'charm',
#   'popularity',
#   'go',
#   'Hyeopjae',
#   'Beach',
#   'becaue',
#   'good',
#   'size',
#   'fantastic',
#   'photogenic',
#   'view',
#   'If',
#   'want',
#   'calmer',
#   'smaller',
#   'le',
#   'crowded',
#   'le',
#   'windy',
#   'beach',
#   'Kumnyoung',
#   'beach',
#   'right',
#   'next',
#   'Hyeopjae',
#   'beach',
#   'It',
#   'good',
#   'younger',
#   'child',
#   'play',
#   'Hyeopjae',
#   'beach',
#   'quite',
#   'windy',
#   'cold',
#   'Of',
#   'course',
#   'Summer',
#   'time',
#   'would',
#   'different',
#   'story',
#   'looking',
#   'forward',
#   'riding',
#   'transparent',
#   'kayak',
#   'operating',
#   'Apr',
#   'There',
#   'number',
#   'banner',
#   'one',
#   'answered'],
#  ['wife',
#   'went',
#   'beach',
#   'beach',
#   'first',
#   'pitstop',
#   'west',
#   'package',
#   'Yeha',
#   'Tour',
#   'The',
#   'place',
#   'cold',
#   'since',
#   'visited',
#   'winter',
#   'season',
#   'But',
#   'scenery',
#   'beautiful',
#   'lovely',
#   'Seriously',
#   'recommended',
#   'honeymoon',
#   'lover'],
#  ['The',
#   'tourist',
#   'industry',
#   'creative',
#   'So',
#   'discovered',
#   'sandy',
#   'patch',
#   'Island',
#   'made',
#   'highlight',
#   'excursion',
#   'Western',
#   'part',
#   'Island',
#   'After',
#   'one',
#   'picture',
#   'leave',
#   'The',
#   'sand',
#   'nice',
#   'however',
#   'took',
#   'sample'],
#  ['Too',
#   'bad',
#   'went',
#   'fall',
#   'would',
#   'wanted',
#   'go',
#   'beautiful',
#   'turquoise',
#   'water',
#   'But',
#   'sat',
#   'front',
#   'beach',
#   'didnt',
#   'realize',
#   'much',
#   'time',
#   'passed',
#   'The',
#   'colour',
#   'impressive',
#   'My',
#   'favorite',
#   'beach',
#   'Jeju'],
#  ['Very',
#   'beautiful',
#   'beach',
#   'although',
#   'one',
#   'ha',
#   'pay',
#   'large',
#   'amount',
#   'spot',
#   'umbrella',
#   'main',
#   'beach',
#   'You',
#   'however',
#   'walk',
#   'bit',
#   'find',
#   'another',
#   'beach',
#   'Beautiful',
#   'beach',
#   'clear',
#   'water',
#   'It',
#   'become',
#   'crowded',
#   'summer',
#   'weekend'],
#  ['If',
#   'coming',
#   'country',
#   'lot',
#   'island',
#   'beach',
#   'like',
#   'Philippines',
#   'place',
#   'omitted',
#   'itinerary',
#   'Food',
#   'drink',
#   'readily',
#   'available',
#   'area',
#   'touristy'],
#  ['Love',
#   'beach',
#   'Sand',
#   'soft',
#   'sea',
#   'beautiful',
#   'We',
#   'walked',
#   'extreme',
#   'left',
#   'peaceful',
#   'quiet',
#   'secluded'],
#  ['This',
#   'beach',
#   'really',
#   'clean',
#   'many',
#   'food',
#   'facility',
#   'available',
#   'There',
#   'free',
#   'parking',
#   'We',
#   'come',
#   'October',
#   'could',
#   'definitely',
#   'see',
#   'place',
#   'full',
#   'people',
#   'summer',
#   'It',
#   'relatively',
#   'close',
#   'Jeju',
#   'city',
#   'ha',
#   'quite',
#   'bit',
#   'offer'],
#  ['Worth',
#   'visit',
#   'beach',
#   'person',
#   'lot',
#   'people',
#   'Plenty',
#   'food',
#   'booth',
#   'shop',
#   'close',
#   'lot',
#   'gimmick',
#   'buy',
#   'include',
#   'day',
#   'Water',
#   'okay',
#   'typical',
#   'sand',
#   'pant',
#   'type',
#   'thing'],
#  ['White',
#   'sand',
#   'clear',
#   'water',
#   'View',
#   'several',
#   'island',
#   'Family',
#   'beach',
#   'Easy',
#   'get',
#   'great',
#   'walk',
#   'along',
#   'water',
#   'edge'],
#  ['It',
#   'tourist',
#   'packed',
#   'beach',
#   'summer',
#   'time',
#   'It',
#   'quite',
#   'expansive',
#   'go',
#   'spot',
#   'thats',
#   'semi',
#   'private',
#   'Recommend',
#   'travel',
#   'outside',
#   'vacation',
#   'period',
#   'unless',
#   'love',
#   'swarm',
#   'family',
#   'child'],
#  ['We',
#   'visited',
#   'beach',
#   'first',
#   'day',
#   'Jeju',
#   'island',
#   'As',
#   'soon',
#   'walked',
#   'felt',
#   'happy',
#   'see',
#   'beautiful',
#   'beach',
#   'It',
#   'beginning',
#   'September',
#   'hot',
#   'soon',
#   'went',
#   'beach',
#   'almost',
#   'got',
#   'frozen',
#   'due',
#   'strong',
#   'wind',
#   'Sand',
#   'white',
#   'combined',
#   'clear',
#   'sky',
#   'water',
#   'appears',
#   'Caribbean',
#   'blue',
#   'difficult',
#   'find',
#   'place',
#   'sit',
#   'overcrowded',
#   'We',
#   'asked',
#   'lady',
#   'local',
#   'shop',
#   'keep',
#   'belonging',
#   'u',
#   'swimming',
#   'kind',
#   'ask',
#   'money',
#   'u',
#   'We',
#   'also',
#   'met',
#   'sunset',
#   'beach',
#   'It',
#   'gorgeous',
#   'Tip',
#   'Take',
#   'windproof',
#   'jacket',
#   'hood',
#   'cannot',
#   'stand',
#   'wind',
#   'long',
#   'time',
#   'Renting',
#   'place',
#   'beach',
#   'umbrella',
#   'cost',
#   '10',
#   '000KRW',
#   'Renting',
#   'inflatable',
#   'toy',
#   'flamingo',
#   'example',
#   'also',
#   '10',
#   '000',
#   'Life',
#   'vest',
#   'goggles',
#   'rent',
#   'also',
#   '10',
#   '000',
#   'And',
#   'see',
#   'price',
#   'tag',
#   'around',
#   'kind',
#   'weird',
#   'Food',
#   'around',
#   'Chinese',
#   'restaurant',
#   'across',
#   'street',
#   'serf',
#   'nice',
#   'jajamyun',
#   'noodle',
#   '000',
#   'KRW',
#   'recommend',
#   'Drinks',
#   'cafe',
#   'bene',
#   'gorgeous',
#   'view',
#   'Average',
#   'coffee',
#   'Good',
#   'bagel',
#   'crab',
#   'meat'],
#  ['Even',
#   'slightly',
#   'overcast',
#   'condition',
#   'pleasant',
#   'stroll',
#   'People',
#   'enjoying',
#   'blue',
#   'water',
#   'peering',
#   'tide',
#   'pool',
#   'Progressed',
#   'lava',
#   'stone',
#   'smooth',
#   'sandy',
#   'beach'],
#  ['Fish',
#   'chip',
#   'shop',
#   'Aussie',
#   'beer',
#   'wine',
#   'African',
#   'Savanna',
#   'cider',
#   'Many',
#   'eatery',
#   'nearby'],
#  ['We',
#   'originally',
#   'got',
#   'bus',
#   'go',
#   'hallim',
#   'park',
#   'noticed',
#   'beautiful',
#   'beach',
#   'decided',
#   'check',
#   'anyway',
#   'ended',
#   'staying',
#   'day',
#   'Was',
#   'nice',
#   'soft',
#   'yellow',
#   'sand',
#   'clear',
#   'water',
#   'There',
#   'quite',
#   'family',
#   'young',
#   'child',
#   'nice',
#   'see',
#   'child',
#   'playing',
#   'Unfortunately',
#   'digger',
#   'truck',
#   'digging',
#   'sand',
#   'hour',
#   'man',
#   'kept',
#   'blowing',
#   'whistle',
#   'everyone',
#   'walking',
#   'near',
#   'truck',
#   'wasnt',
#   'would',
#   'excellent',
#   'Theres',
#   'shop',
#   'restaurant',
#   'close',
#   'toilet',
#   'block',
#   'provide',
#   'flowing',
#   'water',
#   'wash',
#   'cut',
#   'around',
#   'pm',
#   'Sunset',
#   'amazing'],
#  ['Very',
#   'lovely',
#   'shallow',
#   'beach',
#   'good',
#   'snorkeling',
#   'And',
#   'actually',
#   'quite',
#   'famous',
#   'snorkeling',
#   'already',
#   'You',
#   'see',
#   'lot',
#   'young',
#   'people',
#   'summer',
#   'But',
#   'ha',
#   'also',
#   'great',
#   'scenery',
#   'winter'],
#  ['This',
#   'traditional',
#   'beach',
#   'It',
#   'quite',
#   'rocky',
#   'ha',
#   'limited',
#   'sand',
#   'however',
#   'really',
#   'spectacular',
#   'geographical',
#   'feature',
#   'see',
#   'Lots',
#   'restaurant',
#   'nearby',
#   'also',
#   'visit',
#   'Hallim',
#   'park',
#   'hour',
#   'Think',
#   'beach',
#   'would',
#   'better',
#   'height',
#   'summer',
#   'July',
#   'August'],
#  ['This',
#   'great',
#   'beach',
#   'beautiful',
#   'water',
#   'Jeju',
#   'The',
#   'water',
#   'crystal',
#   'clear',
#   'color',
#   'picturesque',
#   'The',
#   'lava',
#   'rock',
#   'add',
#   'beauty',
#   'place'],
#  ['Spent',
#   'Sunday',
#   'morning',
#   'relaxing',
#   'magnificent',
#   'beach',
#   'Its',
#   'emerald',
#   'coloured',
#   'crystal',
#   'clear',
#   'water',
#   'fine',
#   'white',
#   'sand',
#   'laced',
#   'shell',
#   'make',
#   'glitter',
#   'magic',
#   'location',
#   'Cannot',
#   'wait',
#   'moon',
#   'appear',
#   'make',
#   'summer',
#   'complete',
#   'Walk',
#   'way',
#   'round',
#   'Geumneung',
#   'beach',
#   'enjoy',
#   'stroll',
#   'white',
#   'sand'],
#  ['We',
#   'staying',
#   'near',
#   'stopped',
#   'drive',
#   'Great',
#   'photo',
#   'opportunity',
#   'clean',
#   'white',
#   'sand',
#   'You',
#   'take',
#   'dog',
#   'also',
#   'great',
#   'camping',
#   'available',
#   'also',
#   'nice',
#   'little',
#   'stroll',
#   'around',
#   'point',
#   'another',
#   'little',
#   'cove',
#   'also',
#   'Not',
#   'busy',
#   'really',
#   'visited',
#   'No',
#   'swimming',
#   'sign',
#   'everywhere',
#   'great',
#   'paddling',
#   'taking',
#   'In',
#   'view',
#   'The',
#   'sea',
#   'beautifully',
#   'blue',
#   'shallow'],
#  ['This',
#   'one',
#   'beautiful',
#   'beach',
#   'Jeju',
#   'island',
#   'The',
#   'sea',
#   'amazing',
#   'water',
#   'clear',
#   'light',
#   'ocean',
#   'blue',
#   'color',
#   'could',
#   'see',
#   'Biyangdo',
#   'island',
#   'close',
#   'However',
#   'rather',
#   'cold',
#   'windy',
#   'u',
#   'could',
#   'swim',
#   'wandering',
#   'around',
#   'spent',
#   'around',
#   '2hrs',
#   'got',
#   'intercity',
#   'bus',
#   '702',
#   'hr',
#   'jeju',
#   'bus',
#   'terminal'],
#  ['a', 'w', 'a', 'y'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['s', 'i', 'n', 'c', 'e'],
#  ['c', 'o', 'a', 's', 't'],
#  ['h', 'a'],
#  ['l', 'a', 'v', 'a'],
#  ['r', 'o', 'c', 'k'],
#  ['F', 'u', 'n'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['k', 'i', 'd'],
#  ['f', 'i', 'n', 'd'],
#  ['s', 't', 'u', 'f', 'f'],
#  ['r', 'o', 'c', 'k'],
#  ['D', 'o', 'n'],
#  ['j', 'u', 'd', 'g', 'e'],
#  ['k', 'n', 'o', 'w'],
#  ['c', 'o', 'l', 'd'],
#  ['w', 'a', 'n', 't', 'e', 'd'],
#  ['s', 'o', 'm', 'e', 't', 'h', 'i', 'n', 'g'],
#  ['c', 'o', 'o', 'l'],
#  ['B', 'e', 'a', 'c', 'h'],
#  ['w', 'i', 'n', 't', 'e', 'r'],
#  ['L', 'O', 'L'],
#  ['X', 'P'],
#  ['B', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['h', 'i', 'p'],
#  ['a', 'r', 'e', 'a'],
#  ['P', 'l', 'e', 'n', 't', 'y'],
#  ['r', 'e', 'n', 't', 'a', 'l'],
#  ['a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e'],
#  ['g', 'o', 'o', 'd'],
#  ['f', 'o', 'o', 'd'],
#  ['p', 'e', 'r', 'f', 'e', 'c', 't'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['f', 'a', 'm', 'i', 'l', 'y'],
#  ['f', 'u', 'n'],
#  ['V', 'e', 'r', 'y'],
#  ['g', 'o', 'o', 'd'],
#  ['r', 'e', 'l', 'a', 'x'],
#  ['s', 'w', 'i', 'm', 'm', 'i', 'n', 'g'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['S', 'e', 'p', 't', 'e', 'm', 'b', 'e', 'r'],
#  ['h', 'o', 't'],
#  ['I', 'f'],
#  ['t', 'i', 'm', 'e'],
#  ['v', 'i', 's', 'i', 't'],
#  ['n', 'i', 'c', 'e'],
#  ['s', 'm', 'a', 'l', 'l'],
#  ['i', 's', 'l', 'a', 'n', 'd'],
#  ['a', 'h', 'e', 'a', 'd'],
#  ['r', 'e', 'c', 'o', 'm', 'm', 'e', 'n', 'd', 'e', 'd'],
#  ['W', 'o', 'n', 'd', 'e', 'r', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['i', 's', 'l', 'a', 'n', 'd'],
#  ['V', 'e', 'r', 'y'],
#  ['c', 'l', 'e', 'a', 'r'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['A', 'm', 'a', 'z', 'i', 'n', 'g'],
#  ['c', 'o', 'l', 'o', 'r'],
#  ['g', 'o', 'o', 'd'],
#  ['v', 'i', 'b', 'e'],
#  ['a', 'r', 'o', 'u', 'n', 'd'],
#  ['Y', 'o', 'u'],
#  ['s', 'p', 'e', 'n', 'd'],
#  ['o', 'n', 'e'],
#  ['d', 'a', 'y'],
#  ['r', 'e', 'l', 'a', 'x'],
#  ['c', 'h', 'i', 'l', 'l'],
#  ['A', 'n', 'd'],
#  ['I', 'f'],
#  ['w', 'a', 'n', 't'],
#  ['w', 'a', 'l', 'k'],
#  ['a', 'r', 'o', 'u', 'n', 'd'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['c', 'l', 'o', 's', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['l', 'o', 't'],
#  ['r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't'],
#  ['c', 'a', 'f', '챕', 's'],
#  ['T', 'h', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['b', 'u', 's'],
#  ['e', 'a', 's', 'y'],
#  ['g', 'e', 't'],
#  ['b', 'u', 's'],
#  ['s', 't', 'o', 'p'],
#  ['l', 'o', 'c', 'a', 't', 'e', 'd'],
#  ['m', 'i', 'n', 'u', 't', 'e'],
#  ['a', 'w', 'a', 'y'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['c', 'l', 'e', 'a', 'n'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['l', 'o', 'v', 'e', 'l', 'y'],
#  ['b', 'l', 'u', 'e'],
#  ['C', 'a', 'r'],
#  ['p', 'a', 'r', 'k', 'i', 'n', 'g'],
#  ['n', 'e', 'a', 'r'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['n', 'i', 'g', 'h', 't', 'm', 'a', 'r', 'e'],
#  ['m', 'a', 'n', 'y'],
#  ['c', 'a', 'r'],
#  ['c', 'a', 'r'],
#  ['p', 'a', 'r', 'k', 'e', 'd'],
#  ['i', 'm', 'p', 'r', 'o', 'p', 'e', 'r', 'l', 'y'],
#  ['l', 'e', 'a', 's', 't'],
#  ['f', 'r', 'e', 'e'],
#  ['r', 'e', 'a', 'l', 'l', 'y'],
#  ['l', 'i', 'k', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['c', 'l', 'e', 'a', 'n'],
#  ['a', 'l', 't', 'h', 'o', 'u', 'g', 'h'],
#  ['l', 'o', 't'],
#  ['p', 'e', 'o', 'p', 'l', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['e', 'a', 's', 'y'],
#  ['a', 'b', 's', 'o', 'r', 'b'],
#  ['d', 'u', 'e'],
#  ['s', 'i', 'z', 'e'],
#  ['l', 'o', 't'],
#  ['c', 'a', 'f', 'e'],
#  ['c', 'o', 'f', 'f', 'e', 'e'],
#  ['s', 'h', 'o', 'p'],
#  ['n', 'e', 'a', 'r', 'b', 'y'],
#  ['a', 'r', 'r', 'i', 'v', 'e', 'd'],
#  ['l', 'o', 'w'],
#  ['t', 'i', 'd', 'e'],
#  ['s', 'u', 'i', 't', 'a', 'b', 'l', 'e'],
#  ['s', 'w', 'i', 'm', 'm', 'e', 'r'],
#  ['d', 'e', 'e', 'p', 'e', 's', 't'],
#  ['p', 'o', 'i', 'n', 't'],
#  ['n', 'e', 'x', 't'],
#  ['s', 'h', 'a', 'r', 'k'],
#  ['n', 'e', 't'],
#  ['t', 'h', 'i', 'g', 'h'],
#  ['S', 'o'],
#  ['d', 'i', 's', 'a', 'p', 'p', 'o', 'i', 'n', 't', 'e', 'd'],
#  ['m', 'a', 'y', 'b', 'e'],
#  ['l', 'o', 't'],
#  ['b', 'e', 't', 't', 'e', 'r'],
#  ['h', 'i', 'g', 'h'],
#  ['t', 'i', 'd', 'e'],
#  ['A', 'n', 'o', 't', 'h', 'e', 'r'],
#  ['n', 'e', 'g', 'a', 't', 'i', 'v', 'e'],
#  ['p', 'a', 'y'],
#  ['u', 's', 'e'],
#  ['S', 'H', 'O', 'W', 'E', 'R', 'S'],
#  ['3', '0', '0', '0', 'w'],
#  ['a', 'd', 'u', 'l', 't'],
#  ['2', '0', '0', '0', 'w'],
#  ['c', 'h', 'i', 'l', 'd'],
#  ['s', 'h', 'o', 'w', 'e', 'r'],
#  ['g', 'e', 'l'],
#  ['s', 'h', 'a', 'm', 'p', 'o', 'o'],
#  ['a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e'],
#  ['p', 'r', 'i', 'c', 'e'],
#  ['W', 'a', 't', 'e', 'r'],
#  ['c', 'l', 'e', 'a', 'r'],
#  ['s', 'a', 'n', 'd'],
#  ['c', 'l', 'e', 'a', 'n'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['s', 'h', 'o', 'p'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['t', 'o', 'i', 'l', 'e', 't'],
#  ['f', 'a', 'c', 'i', 'l', 'i', 't', 'y'],
#  ['c', 'l', 'o', 's', 'e'],
#  ['P', 'l', 'e', 'n', 't', 'y'],
#  ['e', 'a', 't', 'i', 'n', 'g'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['a', 'r', 'o', 'u', 'n', 'd'],
#  ['a', 'r', 'e', 'a'],
#  ['n', 'i', 'c', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['s', 'p', 'e', 'n', 't'],
#  ['d', 'a', 'y'],
#  ['l', 'i', 't', 't', 'l', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['p', 'e', 'o', 'p', 'l', 'e'],
#  ['f', 'i', 'r', 'i', 'n', 'g'],
#  ['f', 'i', 'r', 'e', 'w', 'o', 'r', 'k'],
#  ['n', 'i', 'g', 'h', 't'],
#  ['S', 'o'],
#  ['h', 'a', 'p', 'p', 'e', 'n'],
#  ['h', 'a', 'p', 'p', 'e', 'n'],
#  ['l', 'i', 'g', 'h', 't'],
#  ['s', 'h', 'o', 'w'],
#  ['M', 'y'],
#  ['g', 'i', 'r', 'l', 'f', 'r', 'i', 'e', 'n', 'd'],
#  ['w', 'e', 'n', 't'],
#  ['w', 'a', 'l', 'k'],
#  ['s', 'a', 't'],
#  ['b', 'e', 'n', 'c', 'h'],
#  ['w', 'a', 't', 'c', 'h'],
#  ['s', 'u', 'n'],
#  ['g', 'o'],
#  ['I', 't'],
#  ['p', 'i', 'c', 't', 'u', 'r', 'e', 's', 'q', 'u', 'e'],
#  ['s', 'e', 't', 't', 'i', 'n', 'g'],
#  ['e', 'n', 'j', 'o', 'y', 'e', 'd'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['h', 'u', 'n', 'd', 'r', 'e', 'd'],
#  ['l', 'i', 't', 't', 'l', 'e'],
#  ['r', 'o', 'c', 'k'],
#  ['p', 'i', 'l', 'e'],
#  ['p', 'e', 'o', 'p', 'l', 'e'],
#  ['b', 'u', 'i', 'l', 't'],
#  ['r', 'e', 'c', 'o', 'm', 'm', 'e', 'n', 'd'],
#  ['s', 'e', 'e', 'i', 'n', 'g'],
#  ['W', 'e'],
#  ['s', 'w', 'i', 'm'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['f', 'e', 'l', 't'],
#  ['g', 'o', 'o', 'd'],
#  ['f', 'o', 'o', 't'],
#  ['S', 'h', 'a', 'n', 'e'],
#  ['J', 'i', 'l', 'l'],
#  ['W', 'e'],
#  ['v', 'i', 's', 'i', 't', 'e', 'd'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['p', 'a', 'r', 't'],
#  ['W', 'e', 's', 't', 'e', 'r', 'n'],
#  ['D', 'i', 's', 'c', 'o', 'v', 'e', 'r', 'y'],
#  ['T', 'o', 'u', 'r'],
#  ['o', 'r', 'g', 'a', 'n', 'i', 'z', 'e', 'd'],
#  ['Y', 'e', 'h', 'a'],
#  ['B', 'u', 's'],
#  ['t', 'o', 'u', 'r'],
#  ['g', 'i', 'v', 'e', 'n'],
#  ['l', 'i', 'm', 'i', 't', 'e', 'd'],
#  ['t', 'i', 'm', 'e'],
#  ['e', 'x', 'p', 'e', 'r', 'i', 'e', 'n', 'c', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['W', 'e'],
#  ['v', 'i', 's', 'i', 't', 'e', 'd'],
#  ['e', 'a', 'r', 'l', 'y'],
#  ['d', 'a', 'y'],
#  ['s', 'p', 'r', 'i', 'n', 'g'],
#  ['s', 't', 'i', 'l', 'l'],
#  ['q', 'u', 'i', 't', 'e'],
#  ['c', 'h', 'i', 'l', 'l', 'y'],
#  ['T', 'h', 'e'],
#  ['v', 'i', 'e', 'w'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['u', 'n', 'd', 'e', 'n', 'i', 'a', 'b', 'l', 'y'],
#  ['b', 'r', 'e', 'a', 't', 'h', 't', 'a', 'k', 'i', 'n', 'g'],
#  ['T', 'e', 'n'],
#  ['m', 'i', 'n', 'u', 't', 'e'],
#  ['e', 'n', 'o', 'u', 'g', 'h'],
#  ['g', 'e', 't'],
#  ['n', 'i', 'c', 'e'],
#  ['s', 'h', 'o', 't'],
#  ['W', 'e'],
#  ['g', 'o'],
#  ['H', 'y', 'e', 'o', 'p', 'j', 'a', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['w', 'h', 'e', 'n', 'e', 'v', 'e', 'r'],
#  ['J', 'e', 'j', 'u'],
#  ['l', 'o', 'v', 'e', 'l', 'y'],
#  ['s', 'a', 'n', 'd'],
#  ['g', 'o', 'o', 'd'],
#  ['s', 'a', 'f', 'e'],
#  ['s', 'w', 'i', 'm', 'm', 'i', 'n', 'g'],
#  ['g', 'r', 'e', 'a', 't'],
#  ['r', 'o', 'c', 'k'],
#  ['c', 'l', 'i', 'm', 'b'],
#  ['g', 'r', 'a', 'n', 'd', 'k', 'i', 'd', 's'],
#  ['l', 'o', 'v', 'e'],
#  ['O', 'f'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['v', 'i', 's', 'i', 't', 'e', 'd'],
#  ['J', 'e', 'j', 'u'],
#  ['o', 'n', 'e'],
#  ['d', 'i', 's', 'a', 'p', 'p', 'o', 'i', 'n', 't', 'i', 'n', 'g'],
#  ['T', 'h', 'e'],
#  ['g', 'r', 'o', 'u', 'n', 'd'],
#  ['s', 'a', 'n', 'd'],
#  ['c', 'o', 'v', 'e', 'r', 'e', 'd'],
#  ['m', 'a', 't', 't', 'i', 'n', 'g'],
#  ['l', 'i', 'k', 'e', 'l', 'y'],
#  ['p', 'r', 'e', 'v', 'e', 'n', 't'],
#  ['e', 'r', 'o', 's', 'i', 'o', 'n'],
#  ['a', 'r', 'e', 'a'],
#  ['s', 'e', 'e', 'm', 'e', 'd'],
#  ['l', 'i', 't', 't', 'l', 'e'],
#  ['u', 'n', 't', 'i', 'd', 'y'],
#  ['T', 'h', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['n', 'i', 'c', 'e'],
#  ['c', 'o', 'm', 'b', 'i', 'n', 'a', 't', 'i', 'o', 'n'],
#  ['s', 'a', 'n', 'd'],
#  ['r', 'o', 'c', 'k'],
#  ['K', 'o', 'r', 'e', 'a', 'n'],
#  ['p', 'e', 'o', 'p', 'l', 'e'],
#  ['u', 's', 'e'],
#  ['E', 'V', 'E', 'R', 'Y'],
#  ['a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e'],
#  ['i', 'n', 'c', 'h'],
#  ['l', 'a', 'n', 'd'],
#  ['T', 'h', 'e', 'y'],
#  ['p', 'u', 'l', 'l'],
#  ['t', 'r', 'a', 'i', 'l', 'e', 'r'],
#  ['c', 'a', 'r'],
#  ['r', 'i', 'g', 'h', 't'],
#  ['e', 'd', 'g', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['s', 'e', 't'],
#  ['c', 'a', 'm', 'p'],
#  ['D', 'o', 'n'],
#  ['u', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd'],
#  ['s', 'w', 'i', 'm', 'm', 'i', 'n', 'g'],
#  ['a', 'l', 'l', 'o', 'w', 'e', 'd'],
#  ['P', 'e', 'o', 'p', 'l', 'e'],
#  ['w', 'a', 'd', 'i', 'n', 'g'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['V', 'i', 's', 'i', 't', 'e', 'd'],
#  ['M', 'o', 'n', 's', 'a', 'n', 't', 'o'],
#  ['c', 'a', 'f', 'e'],
#  ['f', 'o', 'u', 'n', 'd'],
#  ['a', 'f', 'e', 'w'],
#  ['c', 'a', 'f', 'e'],
#  ['n', 'e', 'x', 't'],
#  ['I', 't'],
#  ['m', 'u', 's', 't'],
#  ['g', 'o'],
#  ['l', 'o', 'v', 'e'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['T', 'h', 'e'],
#  ['c', 'o', 'l', 'o', 'u', 'r'],
#  ['H', 'y', 'e', 'o', 'p', 'j', 'a', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['r', 'e', 'a', 'l'],
#  ['e', 'd', 'i', 't', 'e', 'd'],
#  ['I', 't'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['b', 'l', 'a', 'c', 'k'],
#  ['c', 'o', 'r', 'a', 'l'],
#  ['m', 'a', 'k', 'e'],
#  ['p', 'e', 'r', 'f', 'e', 'c', 't'],
#  ['O', 'n', 'e'],
#  ['b', 'e', 's', 't'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['l', 'o', 'v', 'e', 'd'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['c', 'o', 'b', 'a', 'l', 't'],
#  ['c', 'o', 'l', 'o', 'r', 'e', 'd'],
#  ['c', 'r', 'y', 's', 't', 'a', 'l'],
#  ['c', 'l', 'e', 'a', 'r'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['f', 'i', 'n', 'e'],
#  ['w', 'h', 'i', 't', 'e'],
#  ['s', 'a', 'n', 'd'],
#  ['v', 'i', 'e', 'w'],
#  ['M', 'o', 'u', 'n', 't'],
#  ['H', 'a', 'l', 'l', 'a', 's', 'a', 'n'],
#  ['O', 'u', 'r'],
#  ['k', 'i', 'd'],
#  ['e', 'n', 'j', 'o', 'y', 'e', 'd'],
#  ['p', 'l', 'a', 'y', 'i', 'n', 'g'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['c', 'o', 'l', 'l', 'e', 'c', 't', 'i', 'n', 'g'],
#  ['s', 'e', 'a', 's', 'h', 'e', 'l', 'l'],
#  ['e', 'n', 'j', 'o', 'y', 'e', 'd'],
#  ['w', 'a', 'l', 'k', 'i', 'n', 'g'],
#  ['a', 'l', 'o', 'n', 'g'],
#  ['s', 'h', 'o', 'r', 'e'],
#  ['F', 'o', 'o', 'd'],
#  ['s', 't', 'a', 'l', 'l'],
#  ['s', 'h', 'o', 'p'],
#  ['u', 'm', 'b', 'r', 'e', 'l', 'l', 'a'],
#  ['r', 'e', 'n', 't', 'a', 'l'],
#  ['a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e'],
#  ['B', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['s', 'a', 'n', 'd'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['C', 'o', 'u', 'l', 'd', 'n'],
#  ['s', 'w', 'i', 'm'],
#  ['c', 'o', 'z'],
#  ['v', 'i', 's', 'i', 't', 'e', 'd'],
#  ['a', 'u', 't', 'u', 'm', 'n'],
#  ['I', 't'],
#  ['c', 'o', 'l', 'd'],
#  ['u'],
#  ['s', 'w', 'i', 'm'],
#  ['I', 't'],
#  ['a', 'm', 'a', 'z', 'i', 'n', 'g'],
#  ['s', 'e', 'e'],
#  ['l', 'a', 'v', 'a'],
#  ['r', 'o', 'c', 'k'],
#  ['s', 't', 'a', 'c', 'k', 'e', 'd'],
#  ['o', 'n', 'e'],
#  ['c', 'o', 'r', 'n', 'e', 'r'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['W', 'e'],
#  ['n', 'i', 'c', 'e'],
#  ['l', 'u', 'n', 'c', 'h'],
#  ['n', 'e', 'a', 'r', 'b', 'y'],
#  ['L', 'o', 'v', 'e'],
#  ['s', 'e', 'a', 'f', 'o', 'o', 'd'],
#  ['n', 'o', 'o', 'd', 'l', 'e'],
#  ['s', 'o', 'u', 'p'],
#  ['f', 'o', 'r', 'g', 'o', 't'],
#  ['n', 'a', 'm', 'e'],
#  ['r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't'],
#  ['S', 'o', 'r', 'r', 'y'],
#  ['g', 'u', 'y'],
#  ['W', 'e'],
#  ['g', 'l', 'a', 'd'],
#  ['m', 'a', 'n', 'a', 'g', 'e', 'd'],
#  ['c', 'a', 't', 'c', 'h'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['s', 'u', 'n', 's', 'e', 't'],
#  ['H', 'a', 'd'],
#  ['c', 'u', 'p', 'p', 'a'],
#  ['l', 'a', 't', 't', 'e'],
#  ['c', 'a', 'f', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['p', 'l', 'e', 'n', 't', 'y'],
#  ['c', 'a', 'f', 'e'],
#  ['r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't'],
#  ['a', 'r', 'o', 'u', 'n', 'd'],
#  ['P', 'l', 'e', 'n', 't', 'y'],
#  ['p', 'a', 'r', 'k', 'i', 'n', 'g'],
#  ['l', 'o', 't'],
#  ['W', 'o', 'n', 'd', 'e', 'r', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['s', 't', 'a', 'y', 'e', 'd'],
#  ['s', 'h', 'o', 'r', 't'],
#  ['c', 'o', 'f', 'f', 'e', 'e'],
#  ['g', 'r', 'e', 'a', 't'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['r', 'e', 'l', 'a', 'x'],
#  ['g', 'o'],
#  ['e', 'a', 'r', 'l', 'y'],
#  ['a', 'v', 'o', 'i', 'd'],
#  ['c', 'r', 'o', 'w', 'd'],
#  ['I', 't'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['r', 'e', 'a', 'l', 'l', 'y'],
#  ['c', 'o', 'l', 'd'],
#  ['d', 'i', 'p', 'p', 'e', 'd'],
#  ['f', 'o', 'o', 't'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['d', 'i', 'd', 'n', 't'],
#  ['s', 'e', 'e'],
#  ['T', 'h', 'e'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['c', 'l', 'e', 'a', 'r'],
#  ['s', 'u', 'n', 's', 'e', 't'],
#  ['s', 'o', 'o', 'o', 'o'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['W', 'e', 'n', 't'],
#  ['h', 'y', 'e', 'o', 'p', 'j', 'a', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['t', 'r', 'y'],
#  ['s', 'w', 'i', 'm', 'm', 'i', 'n', 'g'],
#  ['J', 'e', 'j', 'u'],
#  ['R', 'e', 'n', 't', 'e', 'd'],
#  ['c', 'a', 'r'],
#  ['d', 'r', 'o', 'v', 'e'],
#  ['t', 'h', 'o', 'u', 'g', 'h', 't'],
#  ['p', 'a', 'r', 'k', 'i', 'n', 'g'],
#  ['g', 'o', 'n', 'n', 'a'],
#  ['c', 'h', 'a', 'l', 'l', 'e', 'n', 'g', 'e'],
#  ['m', 'a', 'n', 'a', 'g', 'e', 'd'],
#  ['g', 'e', 't'],
#  ['o', 'n', 'e'],
#  ['m', 'e', 'r', 'e'],
#  ['m', 'i', 'n', 'u', 't', 'e'],
#  ['M', 'u', 'm'],
#  ['d', 'i', 'd', 'n', 't'],
#  ['s', 'w', 'i', 'm'],
#  ['r', 'e', 'n', 't', 'e', 'd'],
#  ['u', 'm', 'b', 'r', 'e', 'l', 'l', 'a'],
#  ['m', 'a', 't'],
#  ['w', 'a', 'i', 't'],
#  ['C', 'o', 's', 't'],
#  ['u'],
#  ['1', '5', 'K'],
#  ['N', 'o', 't'],
#  ['s', 'u', 'r', 'e'],
#  ['c', 'h', 'e', 'a', 'p'],
#  ['e', 'x', 'p', 'e', 'n', 's', 'i', 'v', 'e'],
#  ['T', 'h', 'e', 'y'],
#  ['g', 'u', 'y'],
#  ['a', 't', 't', 'e', 'n', 'd', 'i', 'n', 'g'],
#  ['r', 'e', 'n', 't', 'a', 'l'],
#  ['s', 'p', 'e', 'a', 'k'],
#  ['e', 'n', 'g', 'l', 'i', 's', 'h'],
#  ['t', 'h', 'a', 'n', 'k'],
#  ['G', 'o', 'd'],
#  ['l', 'o', 'c', 'a', 'l'],
#  ['y', 'o', 'u', 'n', 'g'],
#  ['c', 'h', 'a', 'p'],
#  ['h', 'e', 'l', 'p', 'e', 'd'],
#  ['u'],
#  ['t', 'r', 'a', 'n', 's', 'l', 'a', 't', 'e'],
#  ['L', 'o', 'v', 'e', 'd'],
#  ['v', 'i', 'b', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['e', 'v', 'e', 'r', 'y', 'o', 'n', 'e'],
#  ['e', 'n', 'j', 'o', 'y', 'i', 'n', 'g'],
#  ['w', 'a', 'v', 'e'],
#  ['W', 'h', 'e', 'r', 'e'],
#  ['s', 'e', 'a'],
#  ['r', 'o', 'u', 'g', 'h'],
#  ['r', 'e', 'a', 'l', 'l', 'y'],
#  ['d', 'i', 'f', 'f', 'e', 'r', 'e', 'n', 't'],
#  ['s', 'e', 'e'],
#  ['e', 'v', 'e', 'r', 'y', 'o', 'n', 'e'],
#  ['f', 'l', 'o', 'a', 't', 'i', 'e', 's'],
#  ['w', 'a', 'i', 't', 'i', 'n', 'g'],
#  ['w', 'a', 'v', 'e'],
#  ['h', 'i', 't'],
#  ['I', 'f'],
#  ['w', 'a', 'n', 'n', 'a'],
#  ['e', 'x', 'p', 'e', 'r', 'i', 'e', 'n', 'c', 'e'],
#  ['s', 'w', 'i', 'm'],
#  ['o', 'c', 'e', 'a', 'n'],
#  ['v', 'o', 'l', 'c', 'a', 'n', 'i', 'c'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['Y', 'o', 'u'],
#  ['h', 'i', 'r', 'e'],
#  ['s', 'p', 'o', 't'],
#  ['c', 'o', 'u', 'p', 'l', 'e'],
#  ['h', 'o', 'u', 'r'],
#  ['T', 'h', 'i', 's'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['a', 'd', 'j', 'e', 'c', 'e', 'n', 't'],
#  ['G', 'e', 'u', 'm', 'N', 'e', 'u', 'n', 'g'],
#  ['B', 'e', 'a', 'c', 'h'],
#  ['w', 'a', 'l', 'k'],
#  ['H', 'a', 'l', 'l', 'i', 'm'],
#  ['P', 'a', 'r', 'k'],
#  ['a', 'l', 's', 'o'],
#  ['n', 'e', 'x', 't'],
#  ['w', 'a', 'l', 'k', 'a', 'b', 'l', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['p', 'l', 'e', 'n', 't', 'y'],
#  ['s', 'h', 'o', 'p'],
#  ['u', 'm', 'b', 'r', 'e', 'l', 'l', 'a'],
#  ['r', 'e', 'n', 't', 'a', 'l'],
#  ['e', 't', 'c'],
#  ['C', 'a', 'm', 'p', 'i', 'n', 'g'],
#  ['a', 'v', 'a', 'i', 'a', 'b', 'l', 'e'],
#  ['n', 'e', 'x', 't'],
#  ['d', 'o', 'o', 'r'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['S', 'o', 'm', 'e'],
#  ['a', 'r', 'e', 'a'],
#  ['s', 'w', 'i', 'm', 'm', 'i', 'n', 'g'],
#  ['d', 'u', 'e'],
#  ['s', 't', 'r', 'o', 'n', 'g'],
#  ['c', 'u', 'r', 'r', 'e', 'n', 't'],
#  ['L', 'o', 'v', 'e', 'l', 'y'],
#  ['v', 'i', 'e', 'w'],
#  ['n', 'e', 'a', 'r', 'b', 'y'],
#  ['i', 's', 'l', 'a', 'n', 'd'],
#  ['Y', 'o', 'u'],
#  ['t', 'a', 'k', 'e'],
#  ['2', '0', '2'],
#  ['b', 'u', 's'],
#  ['d', 'a', 'y'],
#  ['m', 'a', 'r', 'k', 'e', 't'],
#  ['n', 'e', 'a', 'r'],
#  ['a', 'i', 'r', 'p', 'o', 'r', 't'],
#  ['T', 'a', 'k', 'e', 's'],
#  ['h', 'o', 'u', 'r'],
#  ['s', 't', 'a', 'y', 'e', 'd'],
#  ['c', 'o', 'u', 'p', 'l', 'e'],
#  ['h', 'o', 'u', 'r'],
#  ['s', 'w', 'a', 'm'],
#  ['e', 'n', 'j', 'o', 'y', 'e', 'd'],
#  ['s', 'u', 'n'],
#  ['d', 'i', 's', 'c', 'u', 's', 's', 'e', 'd'],
#  ['J', 'e', 'j', 'u'],
#  ['r', 'o', 'u', 't'],
#  ['y', 'o', 'u', 'n', 'g'],
#  ['t', 'r', 'a', 'v', 'e', 'l', 'l', 'e', 'r'],
#  ['W', 'e'],
#  ['l', 'a', 'u', 'g', 'h', 'e', 'd'],
#  ['l', 'o', 't'],
#  ['p', 'r', 'a', 'c', 't', 'i', 'c', 'e', 'd'],
#  ['l', 'a', 'n', 'g', 'u', 'a', 'g', 'e'],
#  ['B', 'l', 'a', 'c', 'k'],
#  ['l', 'a', 'v', 'a'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['h', 'a', 'p', 'p', 'y'],
#  ['n', 'o', 'i', 's', 'y'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['T', 'h', 'i', 's'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['g', 'o', 'o', 'd'],
#  ['d', 'e', 'f', 'i', 'n', 'i', 't', 'e', 'l', 'y'],
#  ['w', 'o', 'r', 't', 'h'],
#  ['v', 'i', 's', 'i', 't', 'i', 'n', 'g'],
#  ['A', 'd', 'm', 'i', 't', 't', 'e', 'd', 'l', 'y'],
#  ['l', 'i', 'v', 'e'],
#  ['e', 'x', 'p', 'e', 'c', 't', 'e', 'd'],
#  ['h', 'e', 'a', 'r', 'd'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['h', 'o', 'w', 'e', 'v', 'e', 'r'],
#  ['t', 'h', 'i', 'n', 'k'],
#  ['d', 'u', 'e'],
#  ['l', 'i', 'v', 'i', 'n', 'g'],
#  ['n', 'e', 'a', 'r'],
#  ['G', 'o', 'l', 'd'],
#  ['C', 'o', 'a', 's', 't'],
#  ['S', 'u', 'n', 's', 'h', 'i', 'n', 'e'],
#  ['C', 'o', 'a', 's', 't'],
#  ['A', 'u', 's', 't', 'r', 'a', 'l', 'i', 'a'],
#  ['V', 'e', 'r', 'y'],
#  ['g', 'o', 'o', 'd'],
#  ['m', 'u', 's', 't'],
#  ['s', 'e', 'e'],
#  ['J', 'e', 'j', 'u'],
#  ['S', 't', 'a', 'y', 'e', 'd'],
#  ['H', 'y', 'e', 'o', 'p', 'j', 'a', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['t', 'w', 'o'],
#  ['n', 'i', 'g', 'h', 't'],
#  ['w', 'i', 's', 'h'],
#  ['s', 't', 'a', 'y', 'e', 'd'],
#  ['l', 'o', 'n', 'g', 'e', 'r'],
#  ['L', 'o', 'v', 'e', 'l', 'y'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['r', 'e', 'a', 'l'],
#  ['l', 'o', 'c', 'a', 'l'],
#  ['f', 'e', 'e', 'l', 'i', 'n', 'g'],
#  ['m', 'a', 'n', 'y'],
#  ['c', 'a', 'f', '챕', 's'],
#  ['r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't'],
#  ['a', 'r', 'o', 'u', 'n', 'd'],
#  ['L', 'a', 'r', 'g', 'e'],
#  ['f', 'r', 'e', 'e'],
#  ['c', 'a', 'r'],
#  ['p', 'a', 'r', 'k'],
#  ['D', 'o', 'n'],
#  ['m', 'i', 's', 's'],
#  ['b', 'e', 'e', 'r'],
#  ['b', 'a', 't', 't', 'e', 'r', 'e', 'd'],
#  ['c', 'h', 'i', 'c', 'k', 'e', 'n'],
#  ['b', 'e', 'e', 'r'],
#  ['w', 'a', 'l', 'k'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['o', 'p', 'p', 'o', 's', 'i', 't', 'e'],
#  ['f', 'o', 'o', 't'],
#  ['c', 'l', 'e', 'a', 'n', 'i', 'n', 'g'],
#  ['b', 'a', 't', 'h'],
#  ['W', 'e'],
#  ['m', 'u', 'c', 'h'],
#  ['b', 'e', 't', 't', 'e', 'r'],
#  ['t', 'i', 'm', 'e'],
#  ['H', 'a', 'm', 'd', 'e', 'o', 'k'],
#  ['B', 'e', 'a', 'c', 'h'],
#  ['T', 'h', 'e'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['m', 'u', 'c', 'h'],
#  ['s', 'h', 'a', 'l', 'l', 'o', 'w'],
#  ['f', 'r', 'i', 'e', 'n', 'd', 'l', 'y'],
#  ['s', 'w', 'i', 'm', 'm', 'e', 'r'],
#  ['l', 'e'],
#  ['s', 'e', 'a', 'w', 'e', 'e', 'd'],
#  ['l', 'o', 'w'],
#  ['t', 'i', 'd', 'e'],
#  ['a', 'r', 'e', 'a'],
#  ['T', 'h', 'e'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['c', 'l', 'e', 'a', 'n'],
#  ['c', 'a', 'f', 'e'],
#  ['n', 'e', 'a', 'r', 'b', 'y'],
#  ['c', 'u', 't', 'e'],
#  ['T', 'h', 'i', 's'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['o', 'n', 'e'],
#  ['b', 'e', 'a', 'r', 'i', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['w', 'h', 'i', 't', 'e'],
#  ['s', 'a', 'n', 'd'],
#  ['r', 'e', 'a', 'l', 'l', 'y'],
#  ['g', 'o', 'o', 'd'],
#  ['r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't'],
#  ['c', 'o', 'f', 'f', 'e', 'e', 's', 'h', 'o', 'p', 's'],
#  ['n', 'e', 'a', 'r', 'b', 'y'],
#  ['R', 'e', 'a', 'l', 'l', 'y'],
#  ['r', 'e', 'c', 'o', 'm', 'e', 'n', 'd', 'a', 'b', 'l', 'e'],
#  ['g', 'o'],
#  ['T', 'h', 'i', 's'],
#  ['s', 't', 'r', 'e', 't', 'c', 'h'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['n', 'e', 'a', 'r'],
#  ['H', 'a', 'l', 'l', 'i', 'm'],
#  ['p', 'a', 'r', 'k'],
#  ['W', 'e'],
#  ['h', 'a', 'p', 'p', 'e', 'n', 'e', 'd'],
#  ['d', 'r', 'i', 'v', 'e'],
#  ['s', 't', 'o', 'p', 'p', 'e', 'd'],
#  ['p', 'h', 'o', 't', 'o'],
#  ['t', 'a', 'k', 'i', 'n', 'g'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't'],
#  ['c', 'a', 'f', 'e'],
#  ['a', 'r', 'o', 'u', 'n', 'd'],
#  ['a', 'r', 'e', 'a'],
#  ['c', 'o', 'n', 'v', 'e', 'n', 'i', 'e', 'n', 't'],
#  ['s', 't', 'o', 'r', 'e'],
#  ['T', 'h', 'e'],
#  ['s', 'e', 'a'],
#  ['c', 'l', 'e', 'a', 'r'],
#  ['l', 'o', 't'],
#  ['p', 'e', 'o', 'p', 'l', 'e'],
#  ['l', 'a', 'z', 'i', 'n', 'g'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['W', 'a', 's'],
#  ['s', 'h', 'o', 'r', 't'],
#  ['s', 't', 'o', 'p', 'o', 'v', 'e', 'r'],
#  ['f', 'a', 'm', 'i', 'l', 'y'],
#  ['n', 'i', 'c', 'e'],
#  ['s', 'c', 'e', 'n', 'e', 'r', 'y'],
#  ['h', 'a', 'r', 'm'],
#  ['s', 't', 'o', 'p', 'p', 'i', 'n', 'g'],
#  ['q', 'u', 'i', 'c', 'k'],
#  ['f', 'o', 't', 'o'],
#  ['s', 'h', 'o', 'o', 't'],
#  ['v', 'i', 's', 'i', 't', 'e', 'd'],
#  ['d', 'i', 'f', 'f', 'e', 'r', 'e', 'n', 't'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['T', 'h', 'e', 'y'],
#  ['c', 'h', 'a', 'r', 'm'],
#  ['p', 'o', 'p', 'u', 'l', 'a', 'r', 'i', 't', 'y'],
#  ['g', 'o'],
#  ['H', 'y', 'e', 'o', 'p', 'j', 'a', 'e'],
#  ['B', 'e', 'a', 'c', 'h'],
#  ['b', 'e', 'c', 'a', 'u', 'e'],
#  ['g', 'o', 'o', 'd'],
#  ['s', 'i', 'z', 'e'],
#  ['f', 'a', 'n', 't', 'a', 's', 't', 'i', 'c'],
#  ['p', 'h', 'o', 't', 'o', 'g', 'e', 'n', 'i', 'c'],
#  ['v', 'i', 'e', 'w'],
#  ['I', 'f'],
#  ['w', 'a', 'n', 't'],
#  ['c', 'a', 'l', 'm', 'e', 'r'],
#  ['s', 'm', 'a', 'l', 'l', 'e', 'r'],
#  ['l', 'e'],
#  ['c', 'r', 'o', 'w', 'd', 'e', 'd'],
#  ['l', 'e'],
#  ['w', 'i', 'n', 'd', 'y'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['K', 'u', 'm', 'n', 'y', 'o', 'u', 'n', 'g'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['r', 'i', 'g', 'h', 't'],
#  ['n', 'e', 'x', 't'],
#  ['H', 'y', 'e', 'o', 'p', 'j', 'a', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['I', 't'],
#  ['g', 'o', 'o', 'd'],
#  ['y', 'o', 'u', 'n', 'g', 'e', 'r'],
#  ['c', 'h', 'i', 'l', 'd'],
#  ['p', 'l', 'a', 'y'],
#  ['H', 'y', 'e', 'o', 'p', 'j', 'a', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['q', 'u', 'i', 't', 'e'],
#  ['w', 'i', 'n', 'd', 'y'],
#  ['c', 'o', 'l', 'd'],
#  ['O', 'f'],
#  ['c', 'o', 'u', 'r', 's', 'e'],
#  ['S', 'u', 'm', 'm', 'e', 'r'],
#  ['t', 'i', 'm', 'e'],
#  ['w', 'o', 'u', 'l', 'd'],
#  ['d', 'i', 'f', 'f', 'e', 'r', 'e', 'n', 't'],
#  ['s', 't', 'o', 'r', 'y'],
#  ['l', 'o', 'o', 'k', 'i', 'n', 'g'],
#  ['f', 'o', 'r', 'w', 'a', 'r', 'd'],
#  ['r', 'i', 'd', 'i', 'n', 'g'],
#  ['t', 'r', 'a', 'n', 's', 'p', 'a', 'r', 'e', 'n', 't'],
#  ['k', 'a', 'y', 'a', 'k'],
#  ['o', 'p', 'e', 'r', 'a', 't', 'i', 'n', 'g'],
#  ['A', 'p', 'r'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['n', 'u', 'm', 'b', 'e', 'r'],
#  ['b', 'a', 'n', 'n', 'e', 'r'],
#  ['o', 'n', 'e'],
#  ['a', 'n', 's', 'w', 'e', 'r', 'e', 'd'],
#  ['w', 'i', 'f', 'e'],
#  ['w', 'e', 'n', 't'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['f', 'i', 'r', 's', 't'],
#  ['p', 'i', 't', 's', 't', 'o', 'p'],
#  ['w', 'e', 's', 't'],
#  ['p', 'a', 'c', 'k', 'a', 'g', 'e'],
#  ['Y', 'e', 'h', 'a'],
#  ['T', 'o', 'u', 'r'],
#  ['T', 'h', 'e'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['c', 'o', 'l', 'd'],
#  ['s', 'i', 'n', 'c', 'e'],
#  ['v', 'i', 's', 'i', 't', 'e', 'd'],
#  ['w', 'i', 'n', 't', 'e', 'r'],
#  ['s', 'e', 'a', 's', 'o', 'n'],
#  ['B', 'u', 't'],
#  ['s', 'c', 'e', 'n', 'e', 'r', 'y'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['l', 'o', 'v', 'e', 'l', 'y'],
#  ['S', 'e', 'r', 'i', 'o', 'u', 's', 'l', 'y'],
#  ['r', 'e', 'c', 'o', 'm', 'm', 'e', 'n', 'd', 'e', 'd'],
#  ['h', 'o', 'n', 'e', 'y', 'm', 'o', 'o', 'n'],
#  ['l', 'o', 'v', 'e', 'r'],
#  ['T', 'h', 'e'],
#  ['t', 'o', 'u', 'r', 'i', 's', 't'],
#  ['i', 'n', 'd', 'u', 's', 't', 'r', 'y'],
#  ['c', 'r', 'e', 'a', 't', 'i', 'v', 'e'],
#  ['S', 'o'],
#  ['d', 'i', 's', 'c', 'o', 'v', 'e', 'r', 'e', 'd'],
#  ['s', 'a', 'n', 'd', 'y'],
#  ['p', 'a', 't', 'c', 'h'],
#  ['I', 's', 'l', 'a', 'n', 'd'],
#  ['m', 'a', 'd', 'e'],
#  ['h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't'],
#  ['e', 'x', 'c', 'u', 'r', 's', 'i', 'o', 'n'],
#  ['W', 'e', 's', 't', 'e', 'r', 'n'],
#  ['p', 'a', 'r', 't'],
#  ['I', 's', 'l', 'a', 'n', 'd'],
#  ['A', 'f', 't', 'e', 'r'],
#  ['o', 'n', 'e'],
#  ['p', 'i', 'c', 't', 'u', 'r', 'e'],
#  ['l', 'e', 'a', 'v', 'e'],
#  ['T', 'h', 'e'],
#  ['s', 'a', 'n', 'd'],
#  ['n', 'i', 'c', 'e'],
#  ['h', 'o', 'w', 'e', 'v', 'e', 'r'],
#  ['t', 'o', 'o', 'k'],
#  ['s', 'a', 'm', 'p', 'l', 'e'],
#  ['T', 'o', 'o'],
#  ['b', 'a', 'd'],
#  ['w', 'e', 'n', 't'],
#  ['f', 'a', 'l', 'l'],
#  ['w', 'o', 'u', 'l', 'd'],
#  ['w', 'a', 'n', 't', 'e', 'd'],
#  ['g', 'o'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['t', 'u', 'r', 'q', 'u', 'o', 'i', 's', 'e'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['B', 'u', 't'],
#  ['s', 'a', 't'],
#  ['f', 'r', 'o', 'n', 't'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['d', 'i', 'd', 'n', 't'],
#  ['r', 'e', 'a', 'l', 'i', 'z', 'e'],
#  ['m', 'u', 'c', 'h'],
#  ['t', 'i', 'm', 'e'],
#  ['p', 'a', 's', 's', 'e', 'd'],
#  ['T', 'h', 'e'],
#  ['c', 'o', 'l', 'o', 'u', 'r'],
#  ['i', 'm', 'p', 'r', 'e', 's', 's', 'i', 'v', 'e'],
#  ['M', 'y'],
#  ['f', 'a', 'v', 'o', 'r', 'i', 't', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['V', 'e', 'r', 'y'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['a', 'l', 't', 'h', 'o', 'u', 'g', 'h'],
#  ['o', 'n', 'e'],
#  ['h', 'a'],
#  ['p', 'a', 'y'],
#  ['l', 'a', 'r', 'g', 'e'],
#  ['a', 'm', 'o', 'u', 'n', 't'],
#  ['s', 'p', 'o', 't'],
#  ['u', 'm', 'b', 'r', 'e', 'l', 'l', 'a'],
#  ['m', 'a', 'i', 'n'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['Y', 'o', 'u'],
#  ['h', 'o', 'w', 'e', 'v', 'e', 'r'],
#  ['w', 'a', 'l', 'k'],
#  ['b', 'i', 't'],
#  ['f', 'i', 'n', 'd'],
#  ['a', 'n', 'o', 't', 'h', 'e', 'r'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['B', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['c', 'l', 'e', 'a', 'r'],
#  ['w', 'a', 't', 'e', 'r'],
#  ['I', 't'],
#  ['b', 'e', 'c', 'o', 'm', 'e'],
#  ['c', 'r', 'o', 'w', 'd', 'e', 'd'],
#  ['s', 'u', 'm', 'm', 'e', 'r'],
#  ['w', 'e', 'e', 'k', 'e', 'n', 'd'],
#  ['I', 'f'],
#  ['c', 'o', 'm', 'i', 'n', 'g'],
#  ['c', 'o', 'u', 'n', 't', 'r', 'y'],
#  ['l', 'o', 't'],
#  ['i', 's', 'l', 'a', 'n', 'd'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['l', 'i', 'k', 'e'],
#  ['P', 'h', 'i', 'l', 'i', 'p', 'p', 'i', 'n', 'e', 's'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['o', 'm', 'i', 't', 't', 'e', 'd'],
#  ['i', 't', 'i', 'n', 'e', 'r', 'a', 'r', 'y'],
#  ['F', 'o', 'o', 'd'],
#  ['d', 'r', 'i', 'n', 'k'],
#  ['r', 'e', 'a', 'd', 'i', 'l', 'y'],
#  ['a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e'],
#  ['a', 'r', 'e', 'a'],
#  ['t', 'o', 'u', 'r', 'i', 's', 't', 'y'],
#  ['L', 'o', 'v', 'e'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['S', 'a', 'n', 'd'],
#  ['s', 'o', 'f', 't'],
#  ['s', 'e', 'a'],
#  ['b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l'],
#  ['W', 'e'],
#  ['w', 'a', 'l', 'k', 'e', 'd'],
#  ['e', 'x', 't', 'r', 'e', 'm', 'e'],
#  ['l', 'e', 'f', 't'],
#  ['p', 'e', 'a', 'c', 'e', 'f', 'u', 'l'],
#  ['q', 'u', 'i', 'e', 't'],
#  ['s', 'e', 'c', 'l', 'u', 'd', 'e', 'd'],
#  ['T', 'h', 'i', 's'],
#  ['b', 'e', 'a', 'c', 'h'],
#  ['r', 'e', 'a', 'l', 'l', 'y'],
#  ['c', 'l', 'e', 'a', 'n'],
#  ['m', 'a', 'n', 'y'],
#  ['f', 'o', 'o', 'd'],
#  ['f', 'a', 'c', 'i', 'l', 'i', 't', 'y'],
#  ['a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['f', 'r', 'e', 'e'],
#  ['p', 'a', 'r', 'k', 'i', 'n', 'g'],
#  ['W', 'e'],
#  ['c', 'o', 'm', 'e'],
#  ['O', 'c', 't', 'o', 'b', 'e', 'r'],
#  ['c', 'o', 'u', 'l', 'd'],
#  ['d', 'e', 'f', 'i', 'n', 'i', 't', 'e', 'l', 'y'],
#  ['s', 'e', 'e'],
#  ['p', 'l', 'a', 'c', 'e'],
#  ['f', 'u', 'l', 'l'],
#  ['p', 'e', 'o', 'p', 'l', 'e'],
#  ['s', 'u', 'm', 'm', 'e', 'r'],
#  ['I', 't'],
#  ['r', 'e', 'l', 'a', 't', 'i', 'v', 'e', 'l', 'y'],
#  ['c', 'l', 'o', 's', 'e'],
#  ['J', 'e', 'j', 'u'],
#  ...]

# %%
# Compute bigrams.
from gensim.models import Phrases

# Add bigrams and trigrams to docs (only ones that appear 20 times or more).
bigram = Phrases(result, min_count=20)
for idx,  in enumerate(result):
    for token in bigram[result[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            result[idx].append(token)

# %%
result
# Out:
# [['Hyeopjae',
#   'Beach',
#   'arguably',
#   'picturesque',
#   'beach',
#   'Jeju',
#   'The',
#   'emerald',
#   'colored',
#   'water',
#   'look',
#   'beautiful',
#   'day',
#   'one',
#   'best',
#   'sunset',
#   'spot',
#   'evening',
#   'The',
#   'area',
#   'quite',
#   'busy',
#   'popularity',
#   'beach',
#   'We',
#   'staying',
#   'completely',
#   'opposite',
#   'side',
#   'island',
#   'worth',
#   'long',
#   'drive',
#   'hang',
#   'day'],
#  ['Nice',
#   'view',
#   'nice',
#   'place',
#   'take',
#   'picture',
#   'lot',
#   'beach',
#   'front',
#   'relax',
#   'swim',
#   'Most',
#   'area',
#   'people',
#   'relax',
#   'sunbath',
#   'away',
#   'beach',
#   'since',
#   'coast',
#   'ha',
#   'lava',
#   'rock',
#   'Fun',
#   'place',
#   'kid',
#   'find',
#   'stuff',
#   'rock'],
#  ['Don',
#   'judge',
#   'know',
#   'cold',
#   'wanted',
#   'something',
#   'cool',
#   'Beach',
#   'winter',
#   'LOL',
#   'XP'],
#  ['Beautiful',
#   'beach',
#   'hip',
#   'area',
#   'Plenty',
#   'rental',
#   'available',
#   'good',
#   'food',
#   'perfect',
#   'place',
#   'family',
#   'fun'],
#  ['Very',
#   'good',
#   'relax',
#   'swimming',
#   'water',
#   'September',
#   'hot',
#   'If',
#   'time',
#   'visit',
#   'nice',
#   'small',
#   'island',
#   'ahead',
#   'recommended'],
#  ['Wonderful',
#   'beach',
#   'Jeju',
#   'island',
#   'Very',
#   'clear',
#   'water',
#   'Amazing',
#   'color',
#   'good',
#   'vibe',
#   'around',
#   'You',
#   'spend',
#   'one',
#   'day',
#   'relax',
#   'chill',
#   'And',
#   'If',
#   'want',
#   'walk',
#   'around',
#   'There',
#   'close',
#   'beach',
#   'lot',
#   'restaurant',
#   'caf챕s'],
#  ['The',
#   'beach',
#   'bus',
#   'easy',
#   'get',
#   'bus',
#   'stop',
#   'located',
#   'minute',
#   'away',
#   'beach',
#   'clean',
#   'water',
#   'lovely',
#   'blue'],
#  ['Car',
#   'parking',
#   'near',
#   'beach',
#   'nightmare',
#   'many',
#   'car',
#   'car',
#   'parked',
#   'improperly',
#   'least',
#   'free',
#   'really',
#   'like',
#   'beach',
#   'clean',
#   'although',
#   'lot',
#   'people',
#   'beach',
#   'easy',
#   'absorb',
#   'due',
#   'size',
#   'lot',
#   'cafe',
#   'coffee',
#   'shop',
#   'nearby',
#   'arrived',
#   'low',
#   'tide',
#   'suitable',
#   'swimmer',
#   'deepest',
#   'point',
#   'next',
#   'shark',
#   'net',
#   'thigh',
#   'So',
#   'disappointed',
#   'maybe',
#   'lot',
#   'better',
#   'high',
#   'tide',
#   'Another',
#   'negative',
#   'pay',
#   'use',
#   'SHOWERS',
#   '3000w',
#   'adult',
#   '2000w',
#   'child',
#   'shower',
#   'gel',
#   'shampoo',
#   'available',
#   'price'],
#  ['Water',
#   'clear',
#   'sand',
#   'clean',
#   'There',
#   'shop',
#   'beach',
#   'toilet',
#   'facility',
#   'close',
#   'Plenty',
#   'eating',
#   'place',
#   'around',
#   'area',
#   'nice',
#   'beach',
#   'spent',
#   'day',
#   'little',
#   'There',
#   'people',
#   'firing',
#   'firework',
#   'night',
#   'So',
#   'happen',
#   'happen',
#   'light',
#   'show'],
#  ['My',
#   'girlfriend',
#   'went',
#   'walk',
#   'sat',
#   'bench',
#   'watch',
#   'sun',
#   'go',
#   'It',
#   'picturesque',
#   'setting',
#   'enjoyed',
#   'There',
#   'hundred',
#   'little',
#   'rock',
#   'pile',
#   'people',
#   'built',
#   'recommend',
#   'seeing',
#   'We',
#   'swim',
#   'water',
#   'felt',
#   'good',
#   'foot',
#   'Shane',
#   'Jill'],
#  ['We',
#   'visited',
#   'beautiful',
#   'beach',
#   'part',
#   'Western',
#   'Discovery',
#   'Tour',
#   'organized',
#   'Yeha',
#   'Bus',
#   'tour',
#   'given',
#   'limited',
#   'time',
#   'experience',
#   'beach',
#   'We',
#   'visited',
#   'early',
#   'day',
#   'spring',
#   'still',
#   'quite',
#   'chilly',
#   'The',
#   'view',
#   'beach',
#   'undeniably',
#   'breathtaking',
#   'Ten',
#   'minute',
#   'enough',
#   'get',
#   'nice',
#   'shot'],
#  ['We',
#   'go',
#   'Hyeopjae',
#   'beach',
#   'whenever',
#   'Jeju',
#   'lovely',
#   'sand',
#   'good',
#   'safe',
#   'swimming',
#   'great',
#   'rock',
#   'climb',
#   'grandkids',
#   'love'],
#  ['Of',
#   'beach',
#   'visited',
#   'Jeju',
#   'one',
#   'disappointing',
#   'The',
#   'ground',
#   'sand',
#   'covered',
#   'matting',
#   'likely',
#   'prevent',
#   'erosion',
#   'area',
#   'seemed',
#   'little',
#   'untidy'],
#  ['The',
#   'beach',
#   'nice',
#   'combination',
#   'sand',
#   'rock',
#   'Korean',
#   'people',
#   'use',
#   'EVERY',
#   'available',
#   'inch',
#   'land',
#   'They',
#   'pull',
#   'trailer',
#   'car',
#   'right',
#   'edge',
#   'beach',
#   'set',
#   'camp',
#   'Don',
#   'understand',
#   'swimming',
#   'allowed',
#   'People',
#   'wading',
#   'water'],
#  ['Visited',
#   'Monsanto',
#   'cafe',
#   'found',
#   'afew',
#   'cafe',
#   'next',
#   'It',
#   'must',
#   'go',
#   'love',
#   'beautiful',
#   'beach'],
#  ['The',
#   'colour',
#   'Hyeopjae',
#   'beach',
#   'real',
#   'edited',
#   'It',
#   'beautiful',
#   'black',
#   'coral',
#   'make',
#   'perfect'],
#  ['One',
#   'best',
#   'beach',
#   'Jeju',
#   'loved',
#   'place',
#   'cobalt',
#   'colored',
#   'crystal',
#   'clear',
#   'water',
#   'fine',
#   'white',
#   'sand',
#   'view',
#   'Mount',
#   'Hallasan',
#   'Our',
#   'kid',
#   'enjoyed',
#   'playing',
#   'water',
#   'collecting',
#   'seashell',
#   'enjoyed',
#   'walking',
#   'along',
#   'shore',
#   'Food',
#   'stall',
#   'shop',
#   'umbrella',
#   'rental',
#   'available'],
#  ['Beautiful',
#   'sand',
#   'beach',
#   'Couldn',
#   'swim',
#   'coz',
#   'visited',
#   'autumn',
#   'It',
#   'cold',
#   'u',
#   'swim',
#   'It',
#   'amazing',
#   'see',
#   'lava',
#   'rock',
#   'stacked',
#   'one',
#   'corner',
#   'beach',
#   'We',
#   'nice',
#   'lunch',
#   'nearby',
#   'Love',
#   'seafood',
#   'noodle',
#   'soup',
#   'forgot',
#   'name',
#   'restaurant',
#   'Sorry',
#   'guy'],
#  ['We',
#   'glad',
#   'managed',
#   'catch',
#   'beautiful',
#   'sunset',
#   'Had',
#   'cuppa',
#   'latte',
#   'cafe',
#   'There',
#   'plenty',
#   'cafe',
#   'restaurant',
#   'around',
#   'Plenty',
#   'parking',
#   'lot'],
#  ['Wonderful',
#   'beach',
#   'stayed',
#   'short',
#   'coffee',
#   'great',
#   'place',
#   'relax',
#   'go',
#   'early',
#   'avoid',
#   'crowd'],
#  ['It',
#   'beautiful',
#   'really',
#   'cold',
#   'dipped',
#   'foot',
#   'water',
#   'didnt',
#   'see',
#   'The',
#   'water',
#   'clear',
#   'sunset',
#   'soooo',
#   'beautiful'],
#  ['Went',
#   'hyeopjae',
#   'beach',
#   'try',
#   'swimming',
#   'Jeju',
#   'Rented',
#   'car',
#   'drove',
#   'thought',
#   'parking',
#   'gonna',
#   'challenge',
#   'managed',
#   'get',
#   'one',
#   'mere',
#   'minute',
#   'Mum',
#   'didnt',
#   'swim',
#   'rented',
#   'umbrella',
#   'mat',
#   'wait',
#   'Cost',
#   'u',
#   '15K',
#   'Not',
#   'sure',
#   'cheap',
#   'expensive',
#   'They',
#   'guy',
#   'attending',
#   'rental',
#   'speak',
#   'english',
#   'thank',
#   'God',
#   'local',
#   'young',
#   'chap',
#   'helped',
#   'u',
#   'translate',
#   'Loved',
#   'vibe',
#   'beach',
#   'everyone',
#   'enjoying',
#   'wave',
#   'Where',
#   'sea',
#   'rough',
#   'really',
#   'different',
#   'see',
#   'everyone',
#   'floaties',
#   'waiting',
#   'wave',
#   'hit'],
#  ['If',
#   'wanna',
#   'experience',
#   'swim',
#   'ocean',
#   'volcanic',
#   'water',
#   'place',
#   'You',
#   'hire',
#   'spot',
#   'couple',
#   'hour'],
#  ['This',
#   'beach',
#   'adjecent',
#   'GeumNeung',
#   'Beach',
#   'walk',
#   'Hallim',
#   'Park',
#   'also',
#   'next',
#   'walkable',
#   'There',
#   'plenty',
#   'shop',
#   'umbrella',
#   'rental',
#   'etc',
#   'Camping',
#   'avaiable',
#   'next',
#   'door',
#   'beach',
#   'Some',
#   'area',
#   'swimming',
#   'due',
#   'strong',
#   'current',
#   'Lovely',
#   'view',
#   'nearby',
#   'island',
#   'You',
#   'take',
#   '202',
#   'bus',
#   'day',
#   'market',
#   'near',
#   'airport',
#   'Takes',
#   'hour'],
#  ['stayed',
#   'couple',
#   'hour',
#   'swam',
#   'enjoyed',
#   'sun',
#   'discussed',
#   'Jeju',
#   'rout',
#   'young',
#   'traveller',
#   'We',
#   'laughed',
#   'lot',
#   'practiced',
#   'language',
#   'Black',
#   'lava',
#   'beach',
#   'happy',
#   'noisy',
#   'place'],
#  ['This',
#   'beach',
#   'good',
#   'definitely',
#   'worth',
#   'visiting',
#   'Admittedly',
#   'live',
#   'expected',
#   'heard',
#   'beach',
#   'however',
#   'think',
#   'due',
#   'living',
#   'near',
#   'Gold',
#   'Coast',
#   'Sunshine',
#   'Coast',
#   'Australia',
#   'Very',
#   'good',
#   'must',
#   'see',
#   'Jeju'],
#  ['Stayed',
#   'Hyeopjae',
#   'beach',
#   'two',
#   'night',
#   'wish',
#   'stayed',
#   'longer',
#   'Lovely',
#   'place',
#   'real',
#   'local',
#   'feeling',
#   'many',
#   'caf챕s',
#   'restaurant',
#   'around',
#   'Large',
#   'free',
#   'car',
#   'park',
#   'Don',
#   'miss',
#   'beer',
#   'battered',
#   'chicken',
#   'beer',
#   'walk',
#   'beach',
#   'opposite',
#   'foot',
#   'cleaning',
#   'bath'],
#  ['We',
#   'much',
#   'better',
#   'time',
#   'Hamdeok',
#   'Beach',
#   'The',
#   'water',
#   'much',
#   'shallow',
#   'friendly',
#   'swimmer',
#   'le',
#   'seaweed',
#   'low',
#   'tide',
#   'area',
#   'The',
#   'water',
#   'clean',
#   'cafe',
#   'nearby',
#   'cute'],
#  ['This',
#   'beach',
#   'one',
#   'beariful',
#   'beach',
#   'Jeju',
#   'white',
#   'sand',
#   'really',
#   'good',
#   'restaurant',
#   'coffeeshops',
#   'nearby',
#   'Really',
#   'recomendable',
#   'go'],
#  ['This',
#   'stretch',
#   'beach',
#   'near',
#   'Hallim',
#   'park',
#   'We',
#   'happened',
#   'drive',
#   'stopped',
#   'photo',
#   'taking',
#   'There',
#   'restaurant',
#   'cafe',
#   'around',
#   'area',
#   'convenient',
#   'store',
#   'The',
#   'sea',
#   'clear',
#   'lot',
#   'people',
#   'lazing',
#   'beach',
#   'Was',
#   'short',
#   'stopover',
#   'family',
#   'nice',
#   'scenery',
#   'harm',
#   'stopping',
#   'quick',
#   'foto',
#   'shoot'],
#  ['visited',
#   'different',
#   'beach',
#   'Jeju',
#   'They',
#   'charm',
#   'popularity',
#   'go',
#   'Hyeopjae',
#   'Beach',
#   'becaue',
#   'good',
#   'size',
#   'fantastic',
#   'photogenic',
#   'view',
#   'If',
#   'want',
#   'calmer',
#   'smaller',
#   'le',
#   'crowded',
#   'le',
#   'windy',
#   'beach',
#   'Kumnyoung',
#   'beach',
#   'right',
#   'next',
#   'Hyeopjae',
#   'beach',
#   'It',
#   'good',
#   'younger',
#   'child',
#   'play',
#   'Hyeopjae',
#   'beach',
#   'quite',
#   'windy',
#   'cold',
#   'Of',
#   'course',
#   'Summer',
#   'time',
#   'would',
#   'different',
#   'story',
#   'looking',
#   'forward',
#   'riding',
#   'transparent',
#   'kayak',
#   'operating',
#   'Apr',
#   'There',
#   'number',
#   'banner',
#   'one',
#   'answered'],
#  ['wife',
#   'went',
#   'beach',
#   'beach',
#   'first',
#   'pitstop',
#   'west',
#   'package',
#   'Yeha',
#   'Tour',
#   'The',
#   'place',
#   'cold',
#   'since',
#   'visited',
#   'winter',
#   'season',
#   'But',
#   'scenery',
#   'beautiful',
#   'lovely',
#   'Seriously',
#   'recommended',
#   'honeymoon',
#   'lover'],
#  ['The',
#   'tourist',
#   'industry',
#   'creative',
#   'So',
#   'discovered',
#   'sandy',
#   'patch',
#   'Island',
#   'made',
#   'highlight',
#   'excursion',
#   'Western',
#   'part',
#   'Island',
#   'After',
#   'one',
#   'picture',
#   'leave',
#   'The',
#   'sand',
#   'nice',
#   'however',
#   'took',
#   'sample'],
#  ['Too',
#   'bad',
#   'went',
#   'fall',
#   'would',
#   'wanted',
#   'go',
#   'beautiful',
#   'turquoise',
#   'water',
#   'But',
#   'sat',
#   'front',
#   'beach',
#   'didnt',
#   'realize',
#   'much',
#   'time',
#   'passed',
#   'The',
#   'colour',
#   'impressive',
#   'My',
#   'favorite',
#   'beach',
#   'Jeju'],
#  ['Very',
#   'beautiful',
#   'beach',
#   'although',
#   'one',
#   'ha',
#   'pay',
#   'large',
#   'amount',
#   'spot',
#   'umbrella',
#   'main',
#   'beach',
#   'You',
#   'however',
#   'walk',
#   'bit',
#   'find',
#   'another',
#   'beach',
#   'Beautiful',
#   'beach',
#   'clear',
#   'water',
#   'It',
#   'become',
#   'crowded',
#   'summer',
#   'weekend'],
#  ['If',
#   'coming',
#   'country',
#   'lot',
#   'island',
#   'beach',
#   'like',
#   'Philippines',
#   'place',
#   'omitted',
#   'itinerary',
#   'Food',
#   'drink',
#   'readily',
#   'available',
#   'area',
#   'touristy'],
#  ['Love',
#   'beach',
#   'Sand',
#   'soft',
#   'sea',
#   'beautiful',
#   'We',
#   'walked',
#   'extreme',
#   'left',
#   'peaceful',
#   'quiet',
#   'secluded'],
#  ['This',
#   'beach',
#   'really',
#   'clean',
#   'many',
#   'food',
#   'facility',
#   'available',
#   'There',
#   'free',
#   'parking',
#   'We',
#   'come',
#   'October',
#   'could',
#   'definitely',
#   'see',
#   'place',
#   'full',
#   'people',
#   'summer',
#   'It',
#   'relatively',
#   'close',
#   'Jeju',
#   'city',
#   'ha',
#   'quite',
#   'bit',
#   'offer'],
#  ['Worth',
#   'visit',
#   'beach',
#   'person',
#   'lot',
#   'people',
#   'Plenty',
#   'food',
#   'booth',
#   'shop',
#   'close',
#   'lot',
#   'gimmick',
#   'buy',
#   'include',
#   'day',
#   'Water',
#   'okay',
#   'typical',
#   'sand',
#   'pant',
#   'type',
#   'thing'],
#  ['White',
#   'sand',
#   'clear',
#   'water',
#   'View',
#   'several',
#   'island',
#   'Family',
#   'beach',
#   'Easy',
#   'get',
#   'great',
#   'walk',
#   'along',
#   'water',
#   'edge'],
#  ['It',
#   'tourist',
#   'packed',
#   'beach',
#   'summer',
#   'time',
#   'It',
#   'quite',
#   'expansive',
#   'go',
#   'spot',
#   'thats',
#   'semi',
#   'private',
#   'Recommend',
#   'travel',
#   'outside',
#   'vacation',
#   'period',
#   'unless',
#   'love',
#   'swarm',
#   'family',
#   'child'],
#  ['We',
#   'visited',
#   'beach',
#   'first',
#   'day',
#   'Jeju',
#   'island',
#   'As',
#   'soon',
#   'walked',
#   'felt',
#   'happy',
#   'see',
#   'beautiful',
#   'beach',
#   'It',
#   'beginning',
#   'September',
#   'hot',
#   'soon',
#   'went',
#   'beach',
#   'almost',
#   'got',
#   'frozen',
#   'due',
#   'strong',
#   'wind',
#   'Sand',
#   'white',
#   'combined',
#   'clear',
#   'sky',
#   'water',
#   'appears',
#   'Caribbean',
#   'blue',
#   'difficult',
#   'find',
#   'place',
#   'sit',
#   'overcrowded',
#   'We',
#   'asked',
#   'lady',
#   'local',
#   'shop',
#   'keep',
#   'belonging',
#   'u',
#   'swimming',
#   'kind',
#   'ask',
#   'money',
#   'u',
#   'We',
#   'also',
#   'met',
#   'sunset',
#   'beach',
#   'It',
#   'gorgeous',
#   'Tip',
#   'Take',
#   'windproof',
#   'jacket',
#   'hood',
#   'cannot',
#   'stand',
#   'wind',
#   'long',
#   'time',
#   'Renting',
#   'place',
#   'beach',
#   'umbrella',
#   'cost',
#   '10',
#   '000KRW',
#   'Renting',
#   'inflatable',
#   'toy',
#   'flamingo',
#   'example',
#   'also',
#   '10',
#   '000',
#   'Life',
#   'vest',
#   'goggles',
#   'rent',
#   'also',
#   '10',
#   '000',
#   'And',
#   'see',
#   'price',
#   'tag',
#   'around',
#   'kind',
#   'weird',
#   'Food',
#   'around',
#   'Chinese',
#   'restaurant',
#   'across',
#   'street',
#   'serf',
#   'nice',
#   'jajamyun',
#   'noodle',
#   '000',
#   'KRW',
#   'recommend',
#   'Drinks',
#   'cafe',
#   'bene',
#   'gorgeous',
#   'view',
#   'Average',
#   'coffee',
#   'Good',
#   'bagel',
#   'crab',
#   'meat'],
#  ['Even',
#   'slightly',
#   'overcast',
#   'condition',
#   'pleasant',
#   'stroll',
#   'People',
#   'enjoying',
#   'blue',
#   'water',
#   'peering',
#   'tide',
#   'pool',
#   'Progressed',
#   'lava',
#   'stone',
#   'smooth',
#   'sandy',
#   'beach'],
#  ['Fish',
#   'chip',
#   'shop',
#   'Aussie',
#   'beer',
#   'wine',
#   'African',
#   'Savanna',
#   'cider',
#   'Many',
#   'eatery',
#   'nearby'],
#  ['We',
#   'originally',
#   'got',
#   'bus',
#   'go',
#   'hallim',
#   'park',
#   'noticed',
#   'beautiful',
#   'beach',
#   'decided',
#   'check',
#   'anyway',
#   'ended',
#   'staying',
#   'day',
#   'Was',
#   'nice',
#   'soft',
#   'yellow',
#   'sand',
#   'clear',
#   'water',
#   'There',
#   'quite',
#   'family',
#   'young',
#   'child',
#   'nice',
#   'see',
#   'child',
#   'playing',
#   'Unfortunately',
#   'digger',
#   'truck',
#   'digging',
#   'sand',
#   'hour',
#   'man',
#   'kept',
#   'blowing',
#   'whistle',
#   'everyone',
#   'walking',
#   'near',
#   'truck',
#   'wasnt',
#   'would',
#   'excellent',
#   'Theres',
#   'shop',
#   'restaurant',
#   'close',
#   'toilet',
#   'block',
#   'provide',
#   'flowing',
#   'water',
#   'wash',
#   'cut',
#   'around',
#   'pm',
#   'Sunset',
#   'amazing'],
#  ['Very',
#   'lovely',
#   'shallow',
#   'beach',
#   'good',
#   'snorkeling',
#   'And',
#   'actually',
#   'quite',
#   'famous',
#   'snorkeling',
#   'already',
#   'You',
#   'see',
#   'lot',
#   'young',
#   'people',
#   'summer',
#   'But',
#   'ha',
#   'also',
#   'great',
#   'scenery',
#   'winter'],
#  ['This',
#   'traditional',
#   'beach',
#   'It',
#   'quite',
#   'rocky',
#   'ha',
#   'limited',
#   'sand',
#   'however',
#   'really',
#   'spectacular',
#   'geographical',
#   'feature',
#   'see',
#   'Lots',
#   'restaurant',
#   'nearby',
#   'also',
#   'visit',
#   'Hallim',
#   'park',
#   'hour',
#   'Think',
#   'beach',
#   'would',
#   'better',
#   'height',
#   'summer',
#   'July',
#   'August'],
#  ['This',
#   'great',
#   'beach',
#   'beautiful',
#   'water',
#   'Jeju',
#   'The',
#   'water',
#   'crystal',
#   'clear',
#   'color',
#   'picturesque',
#   'The',
#   'lava',
#   'rock',
#   'add',
#   'beauty',
#   'place'],
#  ['Spent',
#   'Sunday',
#   'morning',
#   'relaxing',
#   'magnificent',
#   'beach',
#   'Its',
#   'emerald',
#   'coloured',
#   'crystal',
#   'clear',
#   'water',
#   'fine',
#   'white',
#   'sand',
#   'laced',
#   'shell',
#   'make',
#   'glitter',
#   'magic',
#   'location',
#   'Cannot',
#   'wait',
#   'moon',
#   'appear',
#   'make',
#   'summer',
#   'complete',
#   'Walk',
#   'way',
#   'round',
#   'Geumneung',
#   'beach',
#   'enjoy',
#   'stroll',
#   'white',
#   'sand'],
#  ['We',
#   'staying',
#   'near',
#   'stopped',
#   'drive',
#   'Great',
#   'photo',
#   'opportunity',
#   'clean',
#   'white',
#   'sand',
#   'You',
#   'take',
#   'dog',
#   'also',
#   'great',
#   'camping',
#   'available',
#   'also',
#   'nice',
#   'little',
#   'stroll',
#   'around',
#   'point',
#   'another',
#   'little',
#   'cove',
#   'also',
#   'Not',
#   'busy',
#   'really',
#   'visited',
#   'No',
#   'swimming',
#   'sign',
#   'everywhere',
#   'great',
#   'paddling',
#   'taking',
#   'In',
#   'view',
#   'The',
#   'sea',
#   'beautifully',
#   'blue',
#   'shallow'],
#  ['This',
#   'one',
#   'beautiful',
#   'beach',
#   'Jeju',
#   'island',
#   'The',
#   'sea',
#   'amazing',
#   'water',
#   'clear',
#   'light',
#   'ocean',
#   'blue',
#   'color',
#   'could',
#   'see',
#   'Biyangdo',
#   'island',
#   'close',
#   'However',
#   'rather',
#   'cold',
#   'windy',
#   'u',
#   'could',
#   'swim',
#   'wandering',
#   'around',
#   'spent',
#   'around',
#   '2hrs',
#   'got',
#   'intercity',
#   'bus',
#   '702',
#   'hr',
#   'jeju',
#   'bus',
#   'terminal'],
#  ['w'],
#  ['b', 'e', 'c', 'h'],
#  ['n', 'c', 'e'],
#  ['c'],
#  ['h'],
#  ['l', 'v'],
#  ['r', 'c', 'k'],
#  ['F', 'u', 'n'],
#  ['p', 'l', 'c', 'e'],
#  ['k'],
#  ['f', 'n'],
#  ['u', 'f', 'f'],
#  ['r', 'c', 'k'],
#  ['D', 'n'],
#  ['j', 'u', 'g', 'e'],
#  ['k', 'n', 'w'],
#  ['c', 'l'],
#  ['w', 'n', 'e'],
#  ['e', 'h', 'n', 'g'],
#  ['c', 'l'],
#  ['B', 'e', 'c', 'h'],
#  ['w', 'n', 'e', 'r'],
#  ['L', 'O', 'L'],
#  ['X', 'P'],
#  ['B', 'e', 'u', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['h', 'p'],
#  ['r', 'e'],
#  ['P', 'l', 'e', 'n'],
#  ['r', 'e', 'n', 'l'],
#  ['v', 'l', 'b', 'l', 'e'],
#  ['g'],
#  ['f'],
#  ['p', 'e', 'r', 'f', 'e', 'c'],
#  ['p', 'l', 'c', 'e'],
#  ['f', 'l'],
#  ['f', 'u', 'n'],
#  ['V', 'e', 'r'],
#  ['g'],
#  ['r', 'e', 'l', 'x'],
#  ['w', 'n', 'g'],
#  ['w', 'e', 'r'],
#  ['S', 'e', 'p', 'e', 'b', 'e', 'r'],
#  ['h'],
#  ['I', 'f'],
#  ['e'],
#  ['v'],
#  ['n', 'c', 'e'],
#  ['l', 'l'],
#  ['l', 'n'],
#  ['h', 'e'],
#  ['r', 'e', 'c', 'e', 'n', 'e'],
#  ['W', 'n', 'e', 'r', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['l', 'n'],
#  ['V', 'e', 'r'],
#  ['c', 'l', 'e', 'r'],
#  ['w', 'e', 'r'],
#  ['A', 'z', 'n', 'g'],
#  ['c', 'l', 'r'],
#  ['g'],
#  ['v', 'b', 'e'],
#  ['r', 'u', 'n'],
#  ['Y', 'u'],
#  ['p', 'e', 'n'],
#  ['n', 'e'],
#  [],
#  ['r', 'e', 'l', 'x'],
#  ['c', 'h', 'l', 'l'],
#  ['A', 'n'],
#  ['I', 'f'],
#  ['w', 'n'],
#  ['w', 'l', 'k'],
#  ['r', 'u', 'n'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['c', 'l', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['l'],
#  ['r', 'e', 'u', 'r', 'n'],
#  ['c', 'f', '챕'],
#  ['T', 'h', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['b', 'u'],
#  ['e'],
#  ['g', 'e'],
#  ['b', 'u'],
#  ['p'],
#  ['l', 'c', 'e'],
#  ['n', 'u', 'e'],
#  ['w'],
#  ['b', 'e', 'c', 'h'],
#  ['c', 'l', 'e', 'n'],
#  ['w', 'e', 'r'],
#  ['l', 'v', 'e', 'l'],
#  ['b', 'l', 'u', 'e'],
#  ['C', 'r'],
#  ['p', 'r', 'k', 'n', 'g'],
#  ['n', 'e', 'r'],
#  ['b', 'e', 'c', 'h'],
#  ['n', 'g', 'h', 'r', 'e'],
#  ['n'],
#  ['c', 'r'],
#  ['c', 'r'],
#  ['p', 'r', 'k', 'e'],
#  ['p', 'r', 'p', 'e', 'r', 'l'],
#  ['l', 'e'],
#  ['f', 'r', 'e', 'e'],
#  ['r', 'e', 'l', 'l'],
#  ['l', 'k', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['c', 'l', 'e', 'n'],
#  ['l', 'h', 'u', 'g', 'h'],
#  ['l'],
#  ['p', 'e', 'p', 'l', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['e'],
#  ['b', 'r', 'b'],
#  ['u', 'e'],
#  ['z', 'e'],
#  ['l'],
#  ['c', 'f', 'e'],
#  ['c', 'f', 'f', 'e', 'e'],
#  ['h', 'p'],
#  ['n', 'e', 'r', 'b'],
#  ['r', 'r', 'v', 'e'],
#  ['l', 'w'],
#  ['e'],
#  ['u', 'b', 'l', 'e'],
#  ['w', 'e', 'r'],
#  ['e', 'e', 'p', 'e'],
#  ['p', 'n'],
#  ['n', 'e', 'x'],
#  ['h', 'r', 'k'],
#  ['n', 'e'],
#  ['h', 'g', 'h'],
#  ['S'],
#  ['p', 'p', 'n', 'e'],
#  ['b', 'e'],
#  ['l'],
#  ['b', 'e', 'e', 'r'],
#  ['h', 'g', 'h'],
#  ['e'],
#  ['A', 'n', 'h', 'e', 'r'],
#  ['n', 'e', 'g', 'v', 'e'],
#  ['p'],
#  ['u', 'e'],
#  ['S', 'H', 'O', 'W', 'E', 'R', 'S'],
#  ['3', '0', '0', '0', 'w'],
#  ['u', 'l'],
#  ['2', '0', '0', '0', 'w'],
#  ['c', 'h', 'l'],
#  ['h', 'w', 'e', 'r'],
#  ['g', 'e', 'l'],
#  ['h', 'p'],
#  ['v', 'l', 'b', 'l', 'e'],
#  ['p', 'r', 'c', 'e'],
#  ['W', 'e', 'r'],
#  ['c', 'l', 'e', 'r'],
#  ['n'],
#  ['c', 'l', 'e', 'n'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['h', 'p'],
#  ['b', 'e', 'c', 'h'],
#  ['l', 'e'],
#  ['f', 'c', 'l'],
#  ['c', 'l', 'e'],
#  ['P', 'l', 'e', 'n'],
#  ['e', 'n', 'g'],
#  ['p', 'l', 'c', 'e'],
#  ['r', 'u', 'n'],
#  ['r', 'e'],
#  ['n', 'c', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['p', 'e', 'n'],
#  [],
#  ['l', 'l', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['p', 'e', 'p', 'l', 'e'],
#  ['f', 'r', 'n', 'g'],
#  ['f', 'r', 'e', 'w', 'r', 'k'],
#  ['n', 'g', 'h'],
#  ['S'],
#  ['h', 'p', 'p', 'e', 'n'],
#  ['h', 'p', 'p', 'e', 'n'],
#  ['l', 'g', 'h'],
#  ['h', 'w'],
#  ['M'],
#  ['g', 'r', 'l', 'f', 'r', 'e', 'n'],
#  ['w', 'e', 'n'],
#  ['w', 'l', 'k'],
#  [],
#  ['b', 'e', 'n', 'c', 'h'],
#  ['w', 'c', 'h'],
#  ['u', 'n'],
#  ['g'],
#  ['I'],
#  ['p', 'c', 'u', 'r', 'e', 'q', 'u', 'e'],
#  ['e', 'n', 'g'],
#  ['e', 'n', 'j', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['h', 'u', 'n', 'r', 'e'],
#  ['l', 'l', 'e'],
#  ['r', 'c', 'k'],
#  ['p', 'l', 'e'],
#  ['p', 'e', 'p', 'l', 'e'],
#  ['b', 'u', 'l'],
#  ['r', 'e', 'c', 'e', 'n'],
#  ['e', 'e', 'n', 'g'],
#  ['W', 'e'],
#  ['w'],
#  ['w', 'e', 'r'],
#  ['f', 'e', 'l'],
#  ['g'],
#  ['f'],
#  ['S', 'h', 'n', 'e'],
#  ['J', 'l', 'l'],
#  ['W', 'e'],
#  ['v', 'e'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['p', 'r'],
#  ['W', 'e', 'e', 'r', 'n'],
#  ['D', 'c', 'v', 'e', 'r'],
#  ['T', 'u', 'r'],
#  ['r', 'g', 'n', 'z', 'e'],
#  ['Y', 'e', 'h'],
#  ['B', 'u'],
#  ['u', 'r'],
#  ['g', 'v', 'e', 'n'],
#  ['l', 'e'],
#  ['e'],
#  ['e', 'x', 'p', 'e', 'r', 'e', 'n', 'c', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['W', 'e'],
#  ['v', 'e'],
#  ['e', 'r', 'l'],
#  [],
#  ['p', 'r', 'n', 'g'],
#  ['l', 'l'],
#  ['q', 'u', 'e'],
#  ['c', 'h', 'l', 'l'],
#  ['T', 'h', 'e'],
#  ['v', 'e', 'w'],
#  ['b', 'e', 'c', 'h'],
#  ['u', 'n', 'e', 'n', 'b', 'l'],
#  ['b', 'r', 'e', 'h', 'k', 'n', 'g'],
#  ['T', 'e', 'n'],
#  ['n', 'u', 'e'],
#  ['e', 'n', 'u', 'g', 'h'],
#  ['g', 'e'],
#  ['n', 'c', 'e'],
#  ['h'],
#  ['W', 'e'],
#  ['g'],
#  ['H', 'e', 'p', 'j', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['w', 'h', 'e', 'n', 'e', 'v', 'e', 'r'],
#  ['J', 'e', 'j', 'u'],
#  ['l', 'v', 'e', 'l'],
#  ['n'],
#  ['g'],
#  ['f', 'e'],
#  ['w', 'n', 'g'],
#  ['g', 'r', 'e'],
#  ['r', 'c', 'k'],
#  ['c', 'l', 'b'],
#  ['g', 'r', 'n', 'k'],
#  ['l', 'v', 'e'],
#  ['O', 'f'],
#  ['b', 'e', 'c', 'h'],
#  ['v', 'e'],
#  ['J', 'e', 'j', 'u'],
#  ['n', 'e'],
#  ['p', 'p', 'n', 'n', 'g'],
#  ['T', 'h', 'e'],
#  ['g', 'r', 'u', 'n'],
#  ['n'],
#  ['c', 'v', 'e', 'r', 'e'],
#  ['n', 'g'],
#  ['l', 'k', 'e', 'l'],
#  ['p', 'r', 'e', 'v', 'e', 'n'],
#  ['e', 'r', 'n'],
#  ['r', 'e'],
#  ['e', 'e', 'e'],
#  ['l', 'l', 'e'],
#  ['u', 'n'],
#  ['T', 'h', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['n', 'c', 'e'],
#  ['c', 'b', 'n', 'n'],
#  ['n'],
#  ['r', 'c', 'k'],
#  ['K', 'r', 'e', 'n'],
#  ['p', 'e', 'p', 'l', 'e'],
#  ['u', 'e'],
#  ['E', 'V', 'E', 'R', 'Y'],
#  ['v', 'l', 'b', 'l', 'e'],
#  ['n', 'c', 'h'],
#  ['l', 'n'],
#  ['T', 'h', 'e'],
#  ['p', 'u', 'l', 'l'],
#  ['r', 'l', 'e', 'r'],
#  ['c', 'r'],
#  ['r', 'g', 'h'],
#  ['e', 'g', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['e'],
#  ['c', 'p'],
#  ['D', 'n'],
#  ['u', 'n', 'e', 'r', 'n'],
#  ['w', 'n', 'g'],
#  ['l', 'l', 'w', 'e'],
#  ['P', 'e', 'p', 'l', 'e'],
#  ['w', 'n', 'g'],
#  ['w', 'e', 'r'],
#  ['V', 'e'],
#  ['M', 'n', 'n'],
#  ['c', 'f', 'e'],
#  ['f', 'u', 'n'],
#  ['f', 'e', 'w'],
#  ['c', 'f', 'e'],
#  ['n', 'e', 'x'],
#  ['I'],
#  ['u'],
#  ['g'],
#  ['l', 'v', 'e'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['T', 'h', 'e'],
#  ['c', 'l', 'u', 'r'],
#  ['H', 'e', 'p', 'j', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['r', 'e', 'l'],
#  ['e', 'e'],
#  ['I'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['b', 'l', 'c', 'k'],
#  ['c', 'r', 'l'],
#  ['k', 'e'],
#  ['p', 'e', 'r', 'f', 'e', 'c'],
#  ['O', 'n', 'e'],
#  ['b', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['l', 'v', 'e'],
#  ['p', 'l', 'c', 'e'],
#  ['c', 'b', 'l'],
#  ['c', 'l', 'r', 'e'],
#  ['c', 'r', 'l'],
#  ['c', 'l', 'e', 'r'],
#  ['w', 'e', 'r'],
#  ['f', 'n', 'e'],
#  ['w', 'h', 'e'],
#  ['n'],
#  ['v', 'e', 'w'],
#  ['M', 'u', 'n'],
#  ['H', 'l', 'l', 'n'],
#  ['O', 'u', 'r'],
#  ['k'],
#  ['e', 'n', 'j', 'e'],
#  ['p', 'l', 'n', 'g'],
#  ['w', 'e', 'r'],
#  ['c', 'l', 'l', 'e', 'c', 'n', 'g'],
#  ['e', 'h', 'e', 'l', 'l'],
#  ['e', 'n', 'j', 'e'],
#  ['w', 'l', 'k', 'n', 'g'],
#  ['l', 'n', 'g'],
#  ['h', 'r', 'e'],
#  ['F'],
#  ['l', 'l'],
#  ['h', 'p'],
#  ['u', 'b', 'r', 'e', 'l', 'l'],
#  ['r', 'e', 'n', 'l'],
#  ['v', 'l', 'b', 'l', 'e'],
#  ['B', 'e', 'u', 'f', 'u', 'l'],
#  ['n'],
#  ['b', 'e', 'c', 'h'],
#  ['C', 'u', 'l', 'n'],
#  ['w'],
#  ['c', 'z'],
#  ['v', 'e'],
#  ['u', 'u', 'n'],
#  ['I'],
#  ['c', 'l'],
#  ['u'],
#  ['w'],
#  ['I'],
#  ['z', 'n', 'g'],
#  ['e', 'e'],
#  ['l', 'v'],
#  ['r', 'c', 'k'],
#  ['c', 'k', 'e'],
#  ['n', 'e'],
#  ['c', 'r', 'n', 'e', 'r'],
#  ['b', 'e', 'c', 'h'],
#  ['W', 'e'],
#  ['n', 'c', 'e'],
#  ['l', 'u', 'n', 'c', 'h'],
#  ['n', 'e', 'r', 'b'],
#  ['L', 'v', 'e'],
#  ['e', 'f'],
#  ['n', 'l', 'e'],
#  ['u', 'p'],
#  ['f', 'r', 'g'],
#  ['n', 'e'],
#  ['r', 'e', 'u', 'r', 'n'],
#  ['S', 'r', 'r'],
#  ['g', 'u'],
#  ['W', 'e'],
#  ['g', 'l'],
#  ['n', 'g', 'e'],
#  ['c', 'c', 'h'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['u', 'n', 'e'],
#  ['H'],
#  ['c', 'u', 'p', 'p'],
#  ['l', 'e'],
#  ['c', 'f', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['p', 'l', 'e', 'n'],
#  ['c', 'f', 'e'],
#  ['r', 'e', 'u', 'r', 'n'],
#  ['r', 'u', 'n'],
#  ['P', 'l', 'e', 'n'],
#  ['p', 'r', 'k', 'n', 'g'],
#  ['l'],
#  ['W', 'n', 'e', 'r', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['e'],
#  ['h', 'r'],
#  ['c', 'f', 'f', 'e', 'e'],
#  ['g', 'r', 'e'],
#  ['p', 'l', 'c', 'e'],
#  ['r', 'e', 'l', 'x'],
#  ['g'],
#  ['e', 'r', 'l'],
#  ['v'],
#  ['c', 'r', 'w'],
#  ['I'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['r', 'e', 'l', 'l'],
#  ['c', 'l'],
#  ['p', 'p', 'e'],
#  ['f'],
#  ['w', 'e', 'r'],
#  ['n'],
#  ['e', 'e'],
#  ['T', 'h', 'e'],
#  ['w', 'e', 'r'],
#  ['c', 'l', 'e', 'r'],
#  ['u', 'n', 'e'],
#  [],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['W', 'e', 'n'],
#  ['h', 'e', 'p', 'j', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['r'],
#  ['w', 'n', 'g'],
#  ['J', 'e', 'j', 'u'],
#  ['R', 'e', 'n', 'e'],
#  ['c', 'r'],
#  ['r', 'v', 'e'],
#  ['h', 'u', 'g', 'h'],
#  ['p', 'r', 'k', 'n', 'g'],
#  ['g', 'n', 'n'],
#  ['c', 'h', 'l', 'l', 'e', 'n', 'g', 'e'],
#  ['n', 'g', 'e'],
#  ['g', 'e'],
#  ['n', 'e'],
#  ['e', 'r', 'e'],
#  ['n', 'u', 'e'],
#  ['M', 'u'],
#  ['n'],
#  ['w'],
#  ['r', 'e', 'n', 'e'],
#  ['u', 'b', 'r', 'e', 'l', 'l'],
#  [],
#  ['w'],
#  ['C'],
#  ['u'],
#  ['1', '5', 'K'],
#  ['N'],
#  ['u', 'r', 'e'],
#  ['c', 'h', 'e', 'p'],
#  ['e', 'x', 'p', 'e', 'n', 'v', 'e'],
#  ['T', 'h', 'e'],
#  ['g', 'u'],
#  ['e', 'n', 'n', 'g'],
#  ['r', 'e', 'n', 'l'],
#  ['p', 'e', 'k'],
#  ['e', 'n', 'g', 'l', 'h'],
#  ['h', 'n', 'k'],
#  ['G'],
#  ['l', 'c', 'l'],
#  ['u', 'n', 'g'],
#  ['c', 'h', 'p'],
#  ['h', 'e', 'l', 'p', 'e'],
#  ['u'],
#  ['r', 'n', 'l', 'e'],
#  ['L', 'v', 'e'],
#  ['v', 'b', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['e', 'v', 'e', 'r', 'n', 'e'],
#  ['e', 'n', 'j', 'n', 'g'],
#  ['w', 'v', 'e'],
#  ['W', 'h', 'e', 'r', 'e'],
#  ['e'],
#  ['r', 'u', 'g', 'h'],
#  ['r', 'e', 'l', 'l'],
#  ['f', 'f', 'e', 'r', 'e', 'n'],
#  ['e', 'e'],
#  ['e', 'v', 'e', 'r', 'n', 'e'],
#  ['f', 'l', 'e'],
#  ['w', 'n', 'g'],
#  ['w', 'v', 'e'],
#  ['h'],
#  ['I', 'f'],
#  ['w', 'n', 'n'],
#  ['e', 'x', 'p', 'e', 'r', 'e', 'n', 'c', 'e'],
#  ['w'],
#  ['c', 'e', 'n'],
#  ['v', 'l', 'c', 'n', 'c'],
#  ['w', 'e', 'r'],
#  ['p', 'l', 'c', 'e'],
#  ['Y', 'u'],
#  ['h', 'r', 'e'],
#  ['p'],
#  ['c', 'u', 'p', 'l', 'e'],
#  ['h', 'u', 'r'],
#  ['T', 'h'],
#  ['b', 'e', 'c', 'h'],
#  ['j', 'e', 'c', 'e', 'n'],
#  ['G', 'e', 'u', 'N', 'e', 'u', 'n', 'g'],
#  ['B', 'e', 'c', 'h'],
#  ['w', 'l', 'k'],
#  ['H', 'l', 'l'],
#  ['P', 'r', 'k'],
#  ['l'],
#  ['n', 'e', 'x'],
#  ['w', 'l', 'k', 'b', 'l', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['p', 'l', 'e', 'n'],
#  ['h', 'p'],
#  ['u', 'b', 'r', 'e', 'l', 'l'],
#  ['r', 'e', 'n', 'l'],
#  ['e', 'c'],
#  ['C', 'p', 'n', 'g'],
#  ['v', 'b', 'l', 'e'],
#  ['n', 'e', 'x'],
#  ['r'],
#  ['b', 'e', 'c', 'h'],
#  ['S', 'e'],
#  ['r', 'e'],
#  ['w', 'n', 'g'],
#  ['u', 'e'],
#  ['r', 'n', 'g'],
#  ['c', 'u', 'r', 'r', 'e', 'n'],
#  ['L', 'v', 'e', 'l'],
#  ['v', 'e', 'w'],
#  ['n', 'e', 'r', 'b'],
#  ['l', 'n'],
#  ['Y', 'u'],
#  ['k', 'e'],
#  ['2', '0', '2'],
#  ['b', 'u'],
#  [],
#  ['r', 'k', 'e'],
#  ['n', 'e', 'r'],
#  ['r', 'p', 'r'],
#  ['T', 'k', 'e'],
#  ['h', 'u', 'r'],
#  ['e'],
#  ['c', 'u', 'p', 'l', 'e'],
#  ['h', 'u', 'r'],
#  ['w'],
#  ['e', 'n', 'j', 'e'],
#  ['u', 'n'],
#  ['c', 'u', 'e'],
#  ['J', 'e', 'j', 'u'],
#  ['r', 'u'],
#  ['u', 'n', 'g'],
#  ['r', 'v', 'e', 'l', 'l', 'e', 'r'],
#  ['W', 'e'],
#  ['l', 'u', 'g', 'h', 'e'],
#  ['l'],
#  ['p', 'r', 'c', 'c', 'e'],
#  ['l', 'n', 'g', 'u', 'g', 'e'],
#  ['B', 'l', 'c', 'k'],
#  ['l', 'v'],
#  ['b', 'e', 'c', 'h'],
#  ['h', 'p', 'p'],
#  ['n'],
#  ['p', 'l', 'c', 'e'],
#  ['T', 'h'],
#  ['b', 'e', 'c', 'h'],
#  ['g'],
#  ['e', 'f', 'n', 'e', 'l'],
#  ['w', 'r', 'h'],
#  ['v', 'n', 'g'],
#  ['A', 'e', 'l'],
#  ['l', 'v', 'e'],
#  ['e', 'x', 'p', 'e', 'c', 'e'],
#  ['h', 'e', 'r'],
#  ['b', 'e', 'c', 'h'],
#  ['h', 'w', 'e', 'v', 'e', 'r'],
#  ['h', 'n', 'k'],
#  ['u', 'e'],
#  ['l', 'v', 'n', 'g'],
#  ['n', 'e', 'r'],
#  ['G', 'l'],
#  ['C'],
#  ['S', 'u', 'n', 'h', 'n', 'e'],
#  ['C'],
#  ['A', 'u', 'r', 'l'],
#  ['V', 'e', 'r'],
#  ['g'],
#  ['u'],
#  ['e', 'e'],
#  ['J', 'e', 'j', 'u'],
#  ['S', 'e'],
#  ['H', 'e', 'p', 'j', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['w'],
#  ['n', 'g', 'h'],
#  ['w', 'h'],
#  ['e'],
#  ['l', 'n', 'g', 'e', 'r'],
#  ['L', 'v', 'e', 'l'],
#  ['p', 'l', 'c', 'e'],
#  ['r', 'e', 'l'],
#  ['l', 'c', 'l'],
#  ['f', 'e', 'e', 'l', 'n', 'g'],
#  ['n'],
#  ['c', 'f', '챕'],
#  ['r', 'e', 'u', 'r', 'n'],
#  ['r', 'u', 'n'],
#  ['L', 'r', 'g', 'e'],
#  ['f', 'r', 'e', 'e'],
#  ['c', 'r'],
#  ['p', 'r', 'k'],
#  ['D', 'n'],
#  [],
#  ['b', 'e', 'e', 'r'],
#  ['b', 'e', 'r', 'e'],
#  ['c', 'h', 'c', 'k', 'e', 'n'],
#  ['b', 'e', 'e', 'r'],
#  ['w', 'l', 'k'],
#  ['b', 'e', 'c', 'h'],
#  ['p', 'p', 'e'],
#  ['f'],
#  ['c', 'l', 'e', 'n', 'n', 'g'],
#  ['b', 'h'],
#  ['W', 'e'],
#  ['u', 'c', 'h'],
#  ['b', 'e', 'e', 'r'],
#  ['e'],
#  ['H', 'e', 'k'],
#  ['B', 'e', 'c', 'h'],
#  ['T', 'h', 'e'],
#  ['w', 'e', 'r'],
#  ['u', 'c', 'h'],
#  ['h', 'l', 'l', 'w'],
#  ['f', 'r', 'e', 'n', 'l'],
#  ['w', 'e', 'r'],
#  ['l', 'e'],
#  ['e', 'w', 'e', 'e'],
#  ['l', 'w'],
#  ['e'],
#  ['r', 'e'],
#  ['T', 'h', 'e'],
#  ['w', 'e', 'r'],
#  ['c', 'l', 'e', 'n'],
#  ['c', 'f', 'e'],
#  ['n', 'e', 'r', 'b'],
#  ['c', 'u', 'e'],
#  ['T', 'h'],
#  ['b', 'e', 'c', 'h'],
#  ['n', 'e'],
#  ['b', 'e', 'r', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['w', 'h', 'e'],
#  ['n'],
#  ['r', 'e', 'l', 'l'],
#  ['g'],
#  ['r', 'e', 'u', 'r', 'n'],
#  ['c', 'f', 'f', 'e', 'e', 'h', 'p'],
#  ['n', 'e', 'r', 'b'],
#  ['R', 'e', 'l', 'l'],
#  ['r', 'e', 'c', 'e', 'n', 'b', 'l', 'e'],
#  ['g'],
#  ['T', 'h'],
#  ['r', 'e', 'c', 'h'],
#  ['b', 'e', 'c', 'h'],
#  ['n', 'e', 'r'],
#  ['H', 'l', 'l'],
#  ['p', 'r', 'k'],
#  ['W', 'e'],
#  ['h', 'p', 'p', 'e', 'n', 'e'],
#  ['r', 'v', 'e'],
#  ['p', 'p', 'e'],
#  ['p', 'h'],
#  ['k', 'n', 'g'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['r', 'e', 'u', 'r', 'n'],
#  ['c', 'f', 'e'],
#  ['r', 'u', 'n'],
#  ['r', 'e'],
#  ['c', 'n', 'v', 'e', 'n', 'e', 'n'],
#  ['r', 'e'],
#  ['T', 'h', 'e'],
#  ['e'],
#  ['c', 'l', 'e', 'r'],
#  ['l'],
#  ['p', 'e', 'p', 'l', 'e'],
#  ['l', 'z', 'n', 'g'],
#  ['b', 'e', 'c', 'h'],
#  ['W'],
#  ['h', 'r'],
#  ['p', 'v', 'e', 'r'],
#  ['f', 'l'],
#  ['n', 'c', 'e'],
#  ['c', 'e', 'n', 'e', 'r'],
#  ['h', 'r'],
#  ['p', 'p', 'n', 'g'],
#  ['q', 'u', 'c', 'k'],
#  ['f'],
#  ['h'],
#  ['v', 'e'],
#  ['f', 'f', 'e', 'r', 'e', 'n'],
#  ['b', 'e', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['T', 'h', 'e'],
#  ['c', 'h', 'r'],
#  ['p', 'p', 'u', 'l', 'r'],
#  ['g'],
#  ['H', 'e', 'p', 'j', 'e'],
#  ['B', 'e', 'c', 'h'],
#  ['b', 'e', 'c', 'u', 'e'],
#  ['g'],
#  ['z', 'e'],
#  ['f', 'n', 'c'],
#  ['p', 'h', 'g', 'e', 'n', 'c'],
#  ['v', 'e', 'w'],
#  ['I', 'f'],
#  ['w', 'n'],
#  ['c', 'l', 'e', 'r'],
#  ['l', 'l', 'e', 'r'],
#  ['l', 'e'],
#  ['c', 'r', 'w', 'e'],
#  ['l', 'e'],
#  ['w', 'n'],
#  ['b', 'e', 'c', 'h'],
#  ['K', 'u', 'n', 'u', 'n', 'g'],
#  ['b', 'e', 'c', 'h'],
#  ['r', 'g', 'h'],
#  ['n', 'e', 'x'],
#  ['H', 'e', 'p', 'j', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['I'],
#  ['g'],
#  ['u', 'n', 'g', 'e', 'r'],
#  ['c', 'h', 'l'],
#  ['p', 'l'],
#  ['H', 'e', 'p', 'j', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['q', 'u', 'e'],
#  ['w', 'n'],
#  ['c', 'l'],
#  ['O', 'f'],
#  ['c', 'u', 'r', 'e'],
#  ['S', 'u', 'e', 'r'],
#  ['e'],
#  ['w', 'u', 'l'],
#  ['f', 'f', 'e', 'r', 'e', 'n'],
#  ['r'],
#  ['l', 'k', 'n', 'g'],
#  ['f', 'r', 'w', 'r'],
#  ['r', 'n', 'g'],
#  ['r', 'n', 'p', 'r', 'e', 'n'],
#  ['k', 'k'],
#  ['p', 'e', 'r', 'n', 'g'],
#  ['A', 'p', 'r'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['n', 'u', 'b', 'e', 'r'],
#  ['b', 'n', 'n', 'e', 'r'],
#  ['n', 'e'],
#  ['n', 'w', 'e', 'r', 'e'],
#  ['w', 'f', 'e'],
#  ['w', 'e', 'n'],
#  ['b', 'e', 'c', 'h'],
#  ['b', 'e', 'c', 'h'],
#  ['f', 'r'],
#  ['p', 'p'],
#  ['w', 'e'],
#  ['p', 'c', 'k', 'g', 'e'],
#  ['Y', 'e', 'h'],
#  ['T', 'u', 'r'],
#  ['T', 'h', 'e'],
#  ['p', 'l', 'c', 'e'],
#  ['c', 'l'],
#  ['n', 'c', 'e'],
#  ['v', 'e'],
#  ['w', 'n', 'e', 'r'],
#  ['e', 'n'],
#  ['B', 'u'],
#  ['c', 'e', 'n', 'e', 'r'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['l', 'v', 'e', 'l'],
#  ['S', 'e', 'r', 'u', 'l'],
#  ['r', 'e', 'c', 'e', 'n', 'e'],
#  ['h', 'n', 'e', 'n'],
#  ['l', 'v', 'e', 'r'],
#  ['T', 'h', 'e'],
#  ['u', 'r'],
#  ['n', 'u', 'r'],
#  ['c', 'r', 'e', 'v', 'e'],
#  ['S'],
#  ['c', 'v', 'e', 'r', 'e'],
#  ['n'],
#  ['p', 'c', 'h'],
#  ['I', 'l', 'n'],
#  ['e'],
#  ['h', 'g', 'h', 'l', 'g', 'h'],
#  ['e', 'x', 'c', 'u', 'r', 'n'],
#  ['W', 'e', 'e', 'r', 'n'],
#  ['p', 'r'],
#  ['I', 'l', 'n'],
#  ['A', 'f', 'e', 'r'],
#  ['n', 'e'],
#  ['p', 'c', 'u', 'r', 'e'],
#  ['l', 'e', 'v', 'e'],
#  ['T', 'h', 'e'],
#  ['n'],
#  ['n', 'c', 'e'],
#  ['h', 'w', 'e', 'v', 'e', 'r'],
#  ['k'],
#  ['p', 'l', 'e'],
#  ['T'],
#  ['b'],
#  ['w', 'e', 'n'],
#  ['f', 'l', 'l'],
#  ['w', 'u', 'l'],
#  ['w', 'n', 'e'],
#  ['g'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['u', 'r', 'q', 'u', 'e'],
#  ['w', 'e', 'r'],
#  ['B', 'u'],
#  [],
#  ['f', 'r', 'n'],
#  ['b', 'e', 'c', 'h'],
#  ['n'],
#  ['r', 'e', 'l', 'z', 'e'],
#  ['u', 'c', 'h'],
#  ['e'],
#  ['p', 'e'],
#  ['T', 'h', 'e'],
#  ['c', 'l', 'u', 'r'],
#  ['p', 'r', 'e', 'v', 'e'],
#  ['M'],
#  ['f', 'v', 'r', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['J', 'e', 'j', 'u'],
#  ['V', 'e', 'r'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['l', 'h', 'u', 'g', 'h'],
#  ['n', 'e'],
#  ['h'],
#  ['p'],
#  ['l', 'r', 'g', 'e'],
#  ['u', 'n'],
#  ['p'],
#  ['u', 'b', 'r', 'e', 'l', 'l'],
#  ['n'],
#  ['b', 'e', 'c', 'h'],
#  ['Y', 'u'],
#  ['h', 'w', 'e', 'v', 'e', 'r'],
#  ['w', 'l', 'k'],
#  ['b'],
#  ['f', 'n'],
#  ['n', 'h', 'e', 'r'],
#  ['b', 'e', 'c', 'h'],
#  ['B', 'e', 'u', 'f', 'u', 'l'],
#  ['b', 'e', 'c', 'h'],
#  ['c', 'l', 'e', 'r'],
#  ['w', 'e', 'r'],
#  ['I'],
#  ['b', 'e', 'c', 'e'],
#  ['c', 'r', 'w', 'e'],
#  ['u', 'e', 'r'],
#  ['w', 'e', 'e', 'k', 'e', 'n'],
#  ['I', 'f'],
#  ['c', 'n', 'g'],
#  ['c', 'u', 'n', 'r'],
#  ['l'],
#  ['l', 'n'],
#  ['b', 'e', 'c', 'h'],
#  ['l', 'k', 'e'],
#  ['P', 'h', 'l', 'p', 'p', 'n', 'e'],
#  ['p', 'l', 'c', 'e'],
#  ['e'],
#  ['n', 'e', 'r', 'r'],
#  ['F'],
#  ['r', 'n', 'k'],
#  ['r', 'e', 'l'],
#  ['v', 'l', 'b', 'l', 'e'],
#  ['r', 'e'],
#  ['u', 'r'],
#  ['L', 'v', 'e'],
#  ['b', 'e', 'c', 'h'],
#  ['S', 'n'],
#  ['f'],
#  ['e'],
#  ['b', 'e', 'u', 'f', 'u', 'l'],
#  ['W', 'e'],
#  ['w', 'l', 'k', 'e'],
#  ['e', 'x', 'r', 'e', 'e'],
#  ['l', 'e', 'f'],
#  ['p', 'e', 'c', 'e', 'f', 'u', 'l'],
#  ['q', 'u', 'e'],
#  ['e', 'c', 'l', 'u', 'e'],
#  ['T', 'h'],
#  ['b', 'e', 'c', 'h'],
#  ['r', 'e', 'l', 'l'],
#  ['c', 'l', 'e', 'n'],
#  ['n'],
#  ['f'],
#  ['f', 'c', 'l'],
#  ['v', 'l', 'b', 'l', 'e'],
#  ['T', 'h', 'e', 'r', 'e'],
#  ['f', 'r', 'e', 'e'],
#  ['p', 'r', 'k', 'n', 'g'],
#  ['W', 'e'],
#  ['c', 'e'],
#  ['O', 'c', 'b', 'e', 'r'],
#  ['c', 'u', 'l'],
#  ['e', 'f', 'n', 'e', 'l'],
#  ['e', 'e'],
#  ['p', 'l', 'c', 'e'],
#  ['f', 'u', 'l', 'l'],
#  ['p', 'e', 'p', 'l', 'e'],
#  ['u', 'e', 'r'],
#  ['I'],
#  ['r', 'e', 'l', 'v', 'e', 'l'],
#  ['c', 'l', 'e'],
#  ['J', 'e', 'j', 'u'],
#  ...]

# %%
# Remove rare and common tokens.
from gensim.corpora import Dictionary

# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.5)

# %%
# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 26
# Number of documents: 1484

# %%
# Train LDA model.
from gensim.models import LdaModel

# Set training parameters.
num_topics = 10
chunksize = 2000
passes = 20
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make an index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)

# %%
top_topics = model.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -4.0547.
# [([(0.4619929, 'o'),
#    (0.11979137, 'd'),
#    (0.09698317, 'r'),
#    (0.07242966, 'c'),
#    (0.07198795, 'g'),
#    (0.06528827, 'l'),
#    (0.03509222, 'f'),
#    (0.031472694, 'v'),
#    (0.026790794, 'w'),
#    (0.013145021, 'k'),
#    (0.0011363172, 't'),
#    (0.0010202777, 'h'),
#    (0.000522638, 'n'),
#    (0.00043699547, 'y'),
#    (0.00024375557, 's'),
#    (0.0002307912, 'a'),
#    (0.000195578, 'm'),
#    (0.0001522967, 'i'),
#    (0.00014101753, 'u'),
#    (0.00014018136, 'p')],
#   -2.21726557873242),
#  ([(0.24734174, 'p'),
#    (0.19435015, 's'),
#    (0.14574559, 'o'),
#    (0.10194424, 'l'),
#    (0.08221102, 'a'),
#    (0.07550208, 't'),
#    (0.043327376, 'c'),
#    (0.042590212, 'r'),
#    (0.036826547, 'h'),
#    (0.013773447, 'i'),
#    (0.010626356, 'y'),
#    (0.0017385904, 'n'),
#    (0.0013007232, 'v'),
#    (0.0006835034, 'd'),
#    (0.00030522127, 'g'),
#    (0.00023222697, 'm'),
#    (0.00016776322, 'k'),
#    (0.00015889213, 'w'),
#    (0.00015547918, 'b'),
#    (0.00015129609, 'f')],
#   -2.3549947177574495),
#  ([(0.59944755, 'u'),
#    (0.08596309, 'j'),
#    (0.07205413, 'b'),
#    (0.06840008, 'l'),
#    (0.045902282, 'y'),
#    (0.034816593, 's'),
#    (0.019509098, 'a'),
#    (0.016188914, 'm'),
#    (0.015399297, 'c'),
#    (0.01516037, 'g'),
#    (0.009358866, 'r'),
#    (0.008139899, 'n'),
#    (0.0020293016, 'd'),
#    (0.0012676186, 't'),
#    (0.001067654, 'o'),
#    (0.0009346816, 'k'),
#    (0.0008534513, 'p'),
#    (0.00073958654, 'h'),
#    (0.00064341, 'i'),
#    (0.00033411788, 'f')],
#   -2.541414477908167),
#  ([(0.21718292, 'm'),
#    (0.13570575, 'a'),
#    (0.1219587, 'k'),
#    (0.11676824, 'i'),
#    (0.1097024, 'n'),
#    (0.076828726, 'w'),
#    (0.066255935, 's'),
#    (0.066218086, 'g'),
#    (0.039441105, 'r'),
#    (0.015696969, 'y'),
#    (0.0146384835, 'p'),
#    (0.011180738, 'l'),
#    (0.0038570152, 'd'),
#    (0.0012755215, 't'),
#    (0.0009790285, 'c'),
#    (0.0003750735, 'h'),
#    (0.00031440565, 'o'),
#    (0.00025893323, 'f'),
#    (0.000186363, 'T'),
#    (0.00018081591, 'b')],
#   -3.1855937775034966),
#  ([(0.33547562, 'l'),
#    (0.16589348, 'a'),
#    (0.12682584, 'f'),
#    (0.12527469, 'i'),
#    (0.0650773, 't'),
#    (0.057187248, 'v'),
#    (0.041185252, 'y'),
#    (0.036126785, 'b'),
#    (0.02113266, 'w'),
#    (0.02020295, 'u'),
#    (0.0026796423, 'c'),
#    (0.00046046157, 'h'),
#    (0.0004516761, 'm'),
#    (0.00024186318, 's'),
#    (0.00017119956, 'o'),
#    (0.00016921273, 'd'),
#    (0.00016082702, 'T'),
#    (0.0001603875, 'n'),
#    (0.00015523593, 'p'),
#    (0.00015203895, 'r')],
#   -3.266674895668921),
#  ([(0.3424434, 'r'),
#    (0.22368802, 'a'),
#    (0.12544966, 't'),
#    (0.09104865, 'n'),
#    (0.050929487, 'y'),
#    (0.04884681, 'w'),
#    (0.038599595, 'W'),
#    (0.025431955, 'l'),
#    (0.015841229, 'g'),
#    (0.013552877, 'b'),
#    (0.01169475, 's'),
#    (0.0075863767, 'u'),
#    (0.0020226147, 'd'),
#    (0.00068034575, 'v'),
#    (0.00032832133, 'i'),
#    (0.00030823285, 'h'),
#    (0.0002707688, 'o'),
#    (0.0002681875, 'f'),
#    (0.00014036799, 'c'),
#    (0.00012931488, 'T')],
#   -4.225763233593573),
#  ([(0.2391262, 'n'),
#    (0.1763563, 'd'),
#    (0.15633205, 'i'),
#    (0.07643998, 's'),
#    (0.07091374, 'a'),
#    (0.06816192, 'beach'),
#    (0.05409065, 't'),
#    (0.050760772, 'y'),
#    (0.046710543, 'g'),
#    (0.02498885, 'v'),
#    (0.023148071, 'c'),
#    (0.005040139, 'j'),
#    (0.004774632, 'o'),
#    (0.0013754683, 'l'),
#    (0.0003513749, 'u'),
#    (0.0002863845, 'r'),
#    (0.00018418542, 'f'),
#    (0.00014777256, 'k'),
#    (0.00013266697, 'w'),
#    (0.000102014776, 'm')],
#   -5.2535200914028675),
#  ([(0.45265463, 'h'),
#    (0.16996773, 'T'),
#    (0.11826679, 'i'),
#    (0.083706245, 'g'),
#    (0.076991335, 't'),
#    (0.05411632, 's'),
#    (0.0148263285, 'y'),
#    (0.009306941, 'n'),
#    (0.00669181, 'p'),
#    (0.0040643257, 'a'),
#    (0.0020272564, 'o'),
#    (0.0015074551, 'k'),
#    (0.0007526798, 'j'),
#    (0.0005482843, 'c'),
#    (0.00046764655, 'l'),
#    (0.0004337909, 'b'),
#    (0.00039552592, 'w'),
#    (0.0003742378, 'u'),
#    (0.00036956373, 'm'),
#    (0.00036312317, 'I')],
#   -5.393325709726028),
#  ([(0.35063228, 'c'),
#    (0.25546882, 'a'),
#    (0.19762616, 'h'),
#    (0.18662289, 'b'),
#    (0.0016332649, 'r'),
#    (0.0015931408, 'd'),
#    (0.0015297, 'm'),
#    (0.00056688325, 'n'),
#    (0.00056041125, 'l'),
#    (0.00044788737, 'i'),
#    (0.00031514012, 'o'),
#    (0.0002882602, 't'),
#    (0.00024373416, 's'),
#    (0.0002247956, 'u'),
#    (0.00020214227, 'v'),
#    (0.0001988828, 'w'),
#    (0.00019565345, 'y'),
#    (0.00019411107, 'T'),
#    (0.00018442117, 'beach'),
#    (0.00018390623, 'k')],
#   -5.663933603827649),
#  ([(0.4302574, 't'),
#    (0.12743206, 'i'),
#    (0.08905464, 's'),
#    (0.08310007, 'u'),
#    (0.073906325, 'n'),
#    (0.051272, 'I'),
#    (0.04580841, 'm'),
#    (0.036622472, 'w'),
#    (0.02849783, 'o'),
#    (0.015039941, 'l'),
#    (0.012210336, 'r'),
#    (0.0032477353, 'y'),
#    (0.0005486423, 'd'),
#    (0.00027759993, 'a'),
#    (0.00025064984, 'f'),
#    (0.00023029029, 'v'),
#    (0.00022690771, 'W'),
#    (0.0002264998, 'beach'),
#    (0.0002258631, 'h'),
#    (0.00022549533, 'b')],
#   -6.4440996026183806)]
